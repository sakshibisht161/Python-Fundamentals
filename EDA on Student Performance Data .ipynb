# %% [markdown]
# # Student Performance Data

# %% [markdown]
# # Import All Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # Import Data

# %%
df = pd.read_csv(r"C:\Users\Dell Latitude 5480\Downloads\archive (6).zip")

# %%
df
# Out:
#        student_id  age  gender school_type parent_education  study_hours  \
# 0               1   14    male      public    post graduate          3.1
# 1               2   18  female      public         graduate          3.7
# 2               3   17  female     private    post graduate          7.9
# 3               4   16   other      public      high school          1.1
# 4               5   16  female      public      high school          1.3
# ...           ...  ...     ...         ...              ...          ...
# 24995       12047   17  female      public              phd          1.8
# 24996        1102   16  female     private          diploma          2.7
# 24997        4422   19   other     private    post graduate          1.0
# 24998        7858   14    male     private          diploma          1.0
# 24999       11621   18   other      public        no formal          0.7
#
#        attendance_percentage internet_access travel_time extra_activities  \
# ...

# %% [markdown]
# # Displaying first 4 records

# %%
df.head(4)
# Out:
#    student_id  age  gender school_type parent_education  study_hours  \
# 0           1   14    male      public    post graduate          3.1
# 1           2   18  female      public         graduate          3.7
# 2           3   17  female     private    post graduate          7.9
# 3           4   16   other      public      high school          1.1
#
#    attendance_percentage internet_access travel_time extra_activities  \
# 0                   84.3             yes     <15 min              yes
# 1                   87.8             yes     >60 min               no
# 2                   65.5              no     <15 min               no
# 3                   58.1              no   15-30 min               no
#
#   study_method  math_score  science_score  english_score  overall_score  \
# 0        notes        42.7           55.4           57.0           53.1
# 1     textbook        57.6           68.8           64.8           61.3
# ...

# %% [markdown]
# # Displaying last 4 records

# %%
df.tail(4)
# Out:
#        student_id  age  gender school_type parent_education  study_hours  \
# 24996        1102   16  female     private          diploma          2.7
# 24997        4422   19   other     private    post graduate          1.0
# 24998        7858   14    male     private          diploma          1.0
# 24999       11621   18   other      public        no formal          0.7
#
#        attendance_percentage internet_access travel_time extra_activities  \
# 24996                   97.1             yes     <15 min               no
# 24997                   63.0             yes     <15 min               no
# 24998                   69.4             yes   15-30 min              yes
# 24999                   60.3             yes   30-60 min               no
#
#       study_method  math_score  science_score  english_score  overall_score  \
# 24996     coaching        64.8           48.2           52.3           56.5
# ...

# %% [markdown]
# # Displaying random 4 records

# %%
df.sample(4)
# Out:
#        student_id  age  gender school_type parent_education  study_hours  \
# 11120       11121   15    male      public    post graduate          2.2
# 731           732   16  female     private          diploma          3.9
# 1101         1102   16  female     private          diploma          2.7
# 15376        5540   19    male     private         graduate          5.4
#
#        attendance_percentage internet_access travel_time extra_activities  \
# 11120                   98.8             yes     <15 min               no
# 731                     83.7             yes     >60 min              yes
# 1101                    97.1             yes     <15 min               no
# 15376                   83.4             yes   30-60 min               no
#
#       study_method  math_score  science_score  english_score  overall_score  \
# 11120  group study        44.3           47.9           82.6           64.4
# ...

# %% [markdown]
# # Checking no of Rows & columns in dataset

# %%
df.shape
# Out:
# (25000, 16)

# %% [markdown]
# # Checking all information of Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   student_id             25000 non-null  int64
#  1   age                    25000 non-null  int64
#  2   gender                 25000 non-null  object
#  3   school_type            25000 non-null  object
#  4   parent_education       25000 non-null  object
#  5   study_hours            25000 non-null  float64
#  6   attendance_percentage  25000 non-null  float64
#  7   internet_access        25000 non-null  object
#  8   travel_time            25000 non-null  object
#  9   extra_activities       25000 non-null  object
#  10  study_method           25000 non-null  object
#  11  math_score             25000 non-null  float64
#  12  science_score          25000 non-null  float64
#  13  english_score          25000 non-null  float64
# ...

# %% [markdown]
# # Statistical Summary of Data

# %%
df.describe()
# Out:
#         student_id           age   study_hours  attendance_percentage  \
# count  25000.00000  25000.000000  25000.000000           25000.000000
# mean    7493.04380     16.482760      4.253224              75.084084
# std     4323.56215      1.703895      2.167541              14.373171
# min        1.00000     14.000000      0.500000              50.000000
# 25%     3743.75000     15.000000      2.400000              62.800000
# 50%     7461.50000     16.000000      4.300000              75.100000
# 75%    11252.00000     18.000000      6.100000              87.500000
# max    15000.00000     19.000000      8.000000             100.000000
#
#          math_score  science_score  english_score  overall_score
# count  25000.000000   25000.000000   25000.000000   25000.000000
# mean      63.785944      63.745320      63.681948      64.006172
# std       20.875262      20.970529      20.792693      18.932025
# min        0.000000       0.000000       0.000000      14.500000
# ...

# %% [markdown]
# # Checking Null values

# %%
df.isnull()
# Out:
#        student_id    age  gender  school_type  parent_education  study_hours  \
# 0           False  False   False        False             False        False
# 1           False  False   False        False             False        False
# 2           False  False   False        False             False        False
# 3           False  False   False        False             False        False
# 4           False  False   False        False             False        False
# ...           ...    ...     ...          ...               ...          ...
# 24995       False  False   False        False             False        False
# 24996       False  False   False        False             False        False
# 24997       False  False   False        False             False        False
# 24998       False  False   False        False             False        False
# 24999       False  False   False        False             False        False
#
# ...

# %% [markdown]
# # Checking Total Null values

# %%
df.isnull().sum()
# Out:
# student_id               0
# age                      0
# gender                   0
# school_type              0
# parent_education         0
# study_hours              0
# attendance_percentage    0
# internet_access          0
# travel_time              0
# extra_activities         0
# study_method             0
# math_score               0
# science_score            0
# english_score            0
# overall_score            0
# final_grade              0
# dtype: int64

# %% [markdown]
# # Transpose of Statistical summary of data

# %%
df.describe().T
# Out:
#                          count         mean          std   min      25%  \
# student_id             25000.0  7493.043800  4323.562150   1.0  3743.75
# age                    25000.0    16.482760     1.703895  14.0    15.00
# study_hours            25000.0     4.253224     2.167541   0.5     2.40
# attendance_percentage  25000.0    75.084084    14.373171  50.0    62.80
# math_score             25000.0    63.785944    20.875262   0.0    48.30
# science_score          25000.0    63.745320    20.970529   0.0    48.20
# english_score          25000.0    63.681948    20.792693   0.0    48.30
# overall_score          25000.0    64.006172    18.932025  14.5    49.00
#
#                           50%      75%      max
# student_id             7461.5  11252.0  15000.0
# age                      16.0     18.0     19.0
# study_hours               4.3      6.1      8.0
# attendance_percentage    75.1     87.5    100.0
# math_score               64.1     80.0    100.0
# ...

# %% [markdown]
# # Checking every elements of total count in a column

# %%
df["parent_education"].value_counts()
# Out:
# parent_education
# diploma          4314
# high school      4205
# post graduate    4196
# graduate         4127
# no formal        4079
# phd              4079
# Name: count, dtype: int64

# %% [markdown]
# # Sorting every elements of total count in a column

# %%
df["parent_education"].value_counts().sort_values()
# Out:
# parent_education
# no formal        4079
# phd              4079
# graduate         4127
# post graduate    4196
# high school      4205
# diploma          4314
# Name: count, dtype: int64

# %% [markdown]
# # Descending order sorting

# %%
df["parent_education"].value_counts().sort_values(ascending = False)
# Out:
# parent_education
# diploma          4314
# high school      4205
# post graduate    4196
# graduate         4127
# no formal        4079
# phd              4079
# Name: count, dtype: int64

# %% [markdown]
# # Sorting every elements based on school_type column

# %%
df.sort_values("school_type")
# Out:
#        student_id  age  gender school_type parent_education  study_hours  \
# 12499       12500   16  female     private      high school          0.8
# 19820       11685   17    male     private      high school          5.8
# 10405       10406   15   other     private         graduate          7.3
# 19818       10864   16  female     private        no formal          3.4
# 10407       10408   16   other     private          diploma          6.9
# ...           ...  ...     ...         ...              ...          ...
# 11150       11151   14   other      public        no formal          6.5
# 11151       11152   14   other      public          diploma          6.8
# 11153       11154   19  female      public         graduate          3.7
# 11082       11083   17  female      public              phd          0.5
# 24999       11621   18   other      public        no formal          0.7
#
#        attendance_percentage internet_access travel_time extra_activities  \
# ...

# %% [markdown]
# # Sorting every elements based on school_type and gender column

# %%
df.sort_values(["school_type","gender"])
# Out:
#        student_id  age  gender school_type parent_education  study_hours  \
# 2               3   17  female     private    post graduate          7.9
# 6               7   14  female     private    post graduate          1.8
# 7               8   18  female     private    post graduate          5.6
# 10             11   17  female     private         graduate          6.1
# 12             13   18  female     private      high school          6.8
# ...           ...  ...     ...         ...              ...          ...
# 24958        5471   17   other      public         graduate          4.8
# 24971       12874   17   other      public        no formal          6.5
# 24975       14458   15   other      public         graduate          5.8
# 24977        5316   17   other      public        no formal          2.0
# 24999       11621   18   other      public        no formal          0.7
#
#        attendance_percentage internet_access travel_time extra_activities  \
# ...

# %% [markdown]
# # unique values show

# %%
df["parent_education"].unique()
# Out:
# array(['post graduate', 'graduate', 'high school', 'no formal', 'diploma',
#        'phd'], dtype=object)

# %% [markdown]
# # show unique values number

# %%
df["parent_education"].nunique()
# Out:
# 6

# %% [markdown]
# # Checking duplicate values

# %%
 df.duplicated().sum()
# Out:
# np.int64(10000)

# %% [markdown]
# # Checking for group by values

# %%
final_grades = df.groupby("final_grade")

# %%
final_grades

# %%
len(df)
# Out:
# 25000

# %%
len("final_grade")
# Out:
# 11

# %%
final_grades.size()
# Out:
# final_grade
# a    1205
# b    2696
# c    6161
# d    6311
# e    5672
# f    2955
# dtype: int64

# %%
final_grades.first()
# Out:
#              student_id  age  gender school_type parent_education  \
# final_grade
# a                    48   19    male     private      high school
# b                     3   17  female     private    post graduate
# c                    11   17  female     private         graduate
# d                     2   18  female      public         graduate
# e                     1   14    male      public    post graduate
# f                     5   16  female      public      high school
#
#              study_hours  attendance_percentage internet_access travel_time  \
# final_grade
# a                    7.8                   60.4             yes     >60 min
# b                    7.9                   65.5              no     <15 min
# c                    6.1                   90.5             yes   15-30 min
# d                    3.7                   87.8             yes     >60 min
# e                    3.1                   84.3             yes     <15 min
# ...

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # Bar chart

# %%
df["parent_education"].value_counts().plot(kind = "bar", color ="m")
# Out:
# <Axes: xlabel='parent_education'>

# %%
df["internet_access"].value_counts().plot(kind = "bar" , color ="g")
# Out:
# <Axes: xlabel='internet_access'>

# %% [markdown]
# # Pie chart

# %%
df["gender"].value_counts().plot(kind = "pie")
# Out:
# <Axes: ylabel='count'>

# %%
df["gender"].value_counts().plot(kind = "pie" , autopct=" %1.1f%% ",title = "gender distribution")
plt.ylabel(' ')
plt.show()

# %%
df["extra_activities"].value_counts().plot(kind = "pie")
# Out:
# <Axes: ylabel='count'>

# %%
df["extra_activities"].value_counts().plot(kind = "pie",autopct=" %1.1f%% ")
plt.ylabel(' ')
plt.show()

# %% [markdown]
# # Count Plot

# %%
sns.countplot(x = "school_type", data = df, hue = "school_type")
# Out:
# <Axes: xlabel='school_type', ylabel='count'>

# %% [markdown]
# # Histplot

# %%
sns.histplot(x = "age" ,data = df ,kde = True ,color ="teal")
plt.show()

# %% [markdown]
# # box plot

# %%
sns.boxplot(x = "study_method" , y = "overall_score" , data = df , hue ="study_method" )
# Out:
# <Axes: xlabel='study_method', ylabel='overall_score'>

# %% [markdown]
# # Scatter plot

# %%
sns.scatterplot(x ="school_type" , y ="age" , data = df , hue = "school_type")
# Out:
# <Axes: xlabel='school_type', ylabel='age'>
