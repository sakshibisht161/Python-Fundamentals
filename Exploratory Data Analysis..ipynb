# %% [markdown]
# # Titanic Dataset

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Dell Latitude 5480\Downloads\archive.zip")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# # Displaying first 4 records

# %%
df.head(4)
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 2          894         0       2         Myles, Mr. Thomas Francis    male
# 3          895         0       3                  Wirz, Mr. Albert    male
#
#     Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 0  34.5      0      0  330911  7.8292   NaN        Q
# 1  47.0      1      0  363272  7.0000   NaN        S
# 2  62.0      0      0  240276  9.6875   NaN        Q
# 3  27.0      0      0  315154  8.6625   NaN        S

# %% [markdown]
# # Displaying last 5 records

# %%
df.tail(5)
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %% [markdown]
# # Displaying random 4 records

# %%
df.sample(4)
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 284         1176         1       3        Rosblom, Miss. Salli Helena  female
# 192         1084         0       3  van Billiard, Master. Walter John    male
# 45           937         0       3    Peltomaki, Mr. Nikolai Johannes    male
# 181         1073         0       1   Compton, Mr. Alexander Taylor Jr    male
#
#       Age  SibSp  Parch             Ticket     Fare Cabin Embarked
# 284   2.0      1      1             370129  20.2125   NaN        S
# 192  11.5      1      1           A/5. 851  14.5000   NaN        S
# 45   25.0      0      0  STON/O 2. 3101291   7.9250   NaN        S
# 181  37.0      1      1           PC 17756  83.1583   E52        C

# %% [markdown]
# # Checking no of Rows & columns in dataset

# %%
df.shape
# Out:
# (418, 12)

# %% [markdown]
# # Checking all information of Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %% [markdown]
# # Statistical Summary of Data

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %% [markdown]
# # Checking Null values

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 413        False     False   False  False  False   True  False  False   False
# 414        False     False   False  False  False  False  False  False   False
# 415        False     False   False  False  False  False  False  False   False
# 416        False     False   False  False  False   True  False  False   False
# 417        False     False   False  False  False   True  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %% [markdown]
# # Checking Total Null values

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# # Transpose of Statistical summary of data

# %%
df.describe().T
# Out:
#              count         mean         std     min       25%        50%  \
# PassengerId  418.0  1100.500000  120.810458  892.00  996.2500  1100.5000
# Survived     418.0     0.363636    0.481622    0.00    0.0000     0.0000
# Pclass       418.0     2.265550    0.841838    1.00    1.0000     3.0000
# Age          332.0    30.272590   14.181209    0.17   21.0000    27.0000
# SibSp        418.0     0.447368    0.896760    0.00    0.0000     0.0000
# Parch        418.0     0.392344    0.981429    0.00    0.0000     0.0000
# Fare         417.0    35.627188   55.907576    0.00    7.8958    14.4542
#
#                  75%        max
# PassengerId  1204.75  1309.0000
# Survived        1.00     1.0000
# Pclass          3.00     3.0000
# Age            39.00    76.0000
# SibSp           1.00     8.0000
# Parch           0.00     9.0000
# Fare           31.50   512.3292

# %% [markdown]
# # Checking every elements of total count in a column

# %%
df["Embarked"].value_counts()
# Out:
# Embarked
# S    270
# C    102
# Q     46
# Name: count, dtype: int64

# %% [markdown]
# # Sorting every elements of total count in a column

# %%
df["Embarked"].value_counts().sort_values()
# Out:
# Embarked
# Q     46
# C    102
# S    270
# Name: count, dtype: int64

# %%
df["Embarked"].value_counts().sort_values(ascending = False)
# Out:
# Embarked
# S    270
# C    102
# Q     46
# Name: count, dtype: int64

# %% [markdown]
# # Sorting every elements based on Embarked column

# %%
df.sort_values('Embarked')
# Out:
#      PassengerId  Survived  Pclass  \
# 208         1100         1       1
# 177         1069         0       1
# 179         1071         1       1
# 181         1073         0       1
# 184         1076         1       1
# ..           ...       ...     ...
# 228         1120         0       3
# 117         1009         1       3
# 226         1118         0       3
# 232         1124         0       3
# 248         1140         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 208                      Rosenbaum, Miss. Edith Louise  female  33.0      0
# 177                    Stengel, Mr. Charles Emil Henry    male  54.0      1
# 179  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...  female  64.0      0
# 181                   Compton, Mr. Alexander Taylor Jr    male  37.0      1
# 184  Douglas, Mrs. Frederick Charles (Mary Helene B...  female  27.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Sorting every elements based on Pclass column

# %%
df.sort_values("Pclass")
# Out:
#      PassengerId  Survived  Pclass  \
# 208         1100         1       1
# 350         1242         1       1
# 122         1014         1       1
# 343         1235         1       1
# 131         1023         0       1
# ..           ...       ...     ...
# 165         1057         1       3
# 163         1055         0       3
# 161         1053         0       3
# 199         1091         1       3
# 417         1309         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 208                      Rosenbaum, Miss. Edith Louise  female  33.0      0
# 350       Greenfield, Mrs. Leo David (Blanche Strouse)  female  45.0      0
# 122                    Schabert, Mrs. Paul (Emma Mock)  female  35.0      1
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0      0
# 131                          Gracie, Col. Archibald IV    male  53.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Checking count of Pclass column

# %%
df["Pclass"].value_counts()
# Out:
# Pclass
# 3    218
# 1    107
# 2     93
# Name: count, dtype: int64

# %%
df.sort_values(["Pclass","Survived"])
# Out:
#      PassengerId  Survived  Pclass                                 Name  \
# 11           903         0       1           Jones, Mr. Charles Cresson
# 20           912         0       1               Rothschild, Mr. Martin
# 23           915         0       1      Williams, Mr. Richard Norris II
# 28           920         0       1              Brady, Mr. John Bertram
# 34           926         0       1             Mock, Mr. Philipp Edmund
# ..           ...       ...     ...                                  ...
# 383         1275         1       3  McNamee, Mrs. Neal (Eileen O'Leary)
# 408         1300         1       3      Riordan, Miss. Johanna Hannah""
# 409         1301         1       3            Peacock, Miss. Treasteall
# 410         1302         1       3               Naughton, Miss. Hannah
# 412         1304         1       3       Henriksson, Miss. Jenny Lovisa
#
#         Sex   Age  SibSp  Parch              Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# # Checking duplicate values

# %%
df .duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Checking for group by values

# %%
survived_pass = df.groupby("Survived")
survived_pass

# %%
len(df)
# Out:
# 418

# %%
len("survived_pass")
# Out:
# 13

# %%
survived_pass.size()
# Out:
# Survived
# 0    266
# 1    152
# dtype: int64

# %%
survived_pass.first()
# Out:
#           PassengerId  Pclass                              Name     Sex   Age  \
# Survived
# 0                 892       3                  Kelly, Mr. James    male  34.5
# 1                 893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0
#
#           SibSp  Parch  Ticket    Fare Cabin Embarked
# Survived
# 0             0      0  330911  7.8292   A21        Q
# 1             1      0  363272  7.0000   B45        S

# %% [markdown]
# # Data Visualization

# %%
df["Survived"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Survived'>

# %% [markdown]
# # To check Embarked ratio

# %%
df["Embarked"].value_counts().plot(kind = "pie")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # To check Embarked ratio

# %%
df["Embarked"].value_counts().plot(kind = "pie" , autopct=" %1.1f%% ", title ="Embarked post distribution")
plt.ylabel(' ')
plt.show()

# %% [markdown]
# # To check Distribution of Passenger Class

# %%
df["Pclass"].value_counts().plot(kind = "bar" ,title ="Distribution of Passenger Class")
plt.xlabel("passenger")
plt.ylabel("count")
plt.show()

# %% [markdown]
# # To Check Ratio of male & female

# %%
df["Sex"].value_counts().plot(kind = "pie" , autopct=" %1.1f%% ", title ="sex distribution")
plt.show()

# %% [markdown]
# # To Check Ratio of male & female

# %%
df["Sex"].value_counts().plot(kind = "bar" , title ="sex distribution")
plt.show()

# %% [markdown]
# # Age Distributuion of Passengers

# %%
sns.histplot(df["Age"])
plt.title(f"Age")
plt.show()

# %%
df["Fare"]
# Out:
# 0        7.8292
# 1        7.0000
# 2        9.6875
# 3        8.6625
# 4       12.2875
#          ...
# 413      8.0500
# 414    108.9000
# 415      7.2500
# 416      8.0500
# 417     22.3583
# Name: Fare, Length: 418, dtype: float64

# %% [markdown]
# # Fare distribution

# %%
sns.histplot(df["Fare"])
plt.title(f"Fare")
plt.show()

# %% [markdown]
# # countplot for Survived people

# %%
sns.countplot(x = "Survived" , data = df)
plt.show()

# %% [markdown]
# # countplot for Survived people

# %%
sns.countplot(x = "Survived" , data = df , hue = "Survived")
plt.show()

# %% [markdown]
# # countplot for Survived people

# %%
sns.countplot(x = "Sex" , data = df)
plt.show()

# %% [markdown]
# # countplot for Survived people

# %%
sns.countplot(x = "Sex" , data = df , hue = "Sex")
plt.show()

# %% [markdown]
# # countplot for Survived people

# %%
sns.countplot(x = "Survived" , hue = "Sex" , data = df)
plt.show()

# %% [markdown]
# # countplot for Survived people

# %%
sns.countplot(x="Pclass", hue = "Survived" , data =df)
plt.show()

# %% [markdown]
# # Histplot for checking Age groups

# %%
sns.histplot(df["Age" ],kde = True)
plt.show()

# %%
sns.displot(df["Sex"])

# %%
sns.displot(data=df,x="Age",hue="Survived",kind='kde',palette=sns.color_palette("bright")[:3],fill=True)
# Out:
# C:\Users\Dell Latitude 5480\AppData\Local\Temp\ipykernel_6580\3114715102.py:1: UserWarning: The palette list has more values (3) than needed (2), which may not be intended.
#   sns.displot(data=df,x="Age",hue="Survived",kind='kde',palette=sns.color_palette("bright")[:3],fill=True)

# %%
sns.displot(data=df,x="Fare",hue="Survived",kind='kde',fill = True)

# %%
sns.displot(data=df,x="Pclass",hue="Survived",kind='kde',fill = True)

# %%
sns.pairplot(df,hue="Survived")
