# %% [markdown]
# House Price Pridiction

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# #data read

# %%
df = pd.read_csv(r"C:\Users\Dell Latitude 5480\Downloads\archive (3).zip")

# %%
df
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0        1  1360         5          4       3       1970  Downtown  Excellent
# 1        2  4272         5          4       3       1958  Downtown  Excellent
# 2        3  3592         2          2       3       1938  Downtown       Good
# 3        4   966         4          2       2       1902  Suburban       Fair
# 4        5  4926         1          4       2       1975  Downtown       Fair
# ...    ...   ...       ...        ...     ...        ...       ...        ...
# 1995  1996  4994         5          4       3       1923  Suburban       Poor
# 1996  1997  3046         5          2       1       2019  Suburban       Poor
# 1997  1998  1062         5          1       2       1903     Rural       Poor
# 1998  1999  4062         3          1       2       1936     Urban  Excellent
# 1999  2000  2989         5          1       3       1903  Suburban       Fair
#
#      Garage   Price
# ...

# %% [markdown]
# #Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Id         2000 non-null   int64
#  1   Area       2000 non-null   int64
#  2   Bedrooms   2000 non-null   int64
#  3   Bathrooms  2000 non-null   int64
#  4   Floors     2000 non-null   int64
#  5   YearBuilt  2000 non-null   int64
#  6   Location   2000 non-null   object
#  7   Condition  2000 non-null   object
#  8   Garage     2000 non-null   object
#  9   Price      2000 non-null   int64
# dtypes: int64(7), object(3)
# memory usage: 156.4+ KB

# %% [markdown]
# #Head

# %%
df.head(3)
# Out:
#    Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0   1  1360         5          4       3       1970  Downtown  Excellent
# 1   2  4272         5          4       3       1958  Downtown  Excellent
# 2   3  3592         2          2       3       1938  Downtown       Good
#
#   Garage   Price
# 0     No  149919
# 1     No  424998
# 2     No  266746

# %% [markdown]
# #Tail

# %%
df.tail(3)
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 1997  1998  1062         5          1       2       1903     Rural       Poor
# 1998  1999  4062         3          1       2       1936     Urban  Excellent
# 1999  2000  2989         5          1       3       1903  Suburban       Fair
#
#      Garage   Price
# 1997     No  476925
# 1998    Yes  161119
# 1999     No  482525

# %% [markdown]
# #Sample

# %%
df.sample(2)
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location Condition  \
# 1848  1849  2690         3          1       1       1925  Suburban      Good
# 51      52  2085         2          3       2       1935     Urban      Poor
#
#      Garage   Price
# 1848     No  550884
# 51      Yes  405446

# %% [markdown]
# #Columns

# %%
df.columns
# Out:
# Index(['Id', 'Area', 'Bedrooms', 'Bathrooms', 'Floors', 'YearBuilt',
#        'Location', 'Condition', 'Garage', 'Price'],
#       dtype='object')

# %% [markdown]
# #Shape

# %%
df.shape
# Out:
# (2000, 10)

# %% [markdown]
# #Data Type

# %%
df.dtypes
# Out:
# Id            int64
# Area          int64
# Bedrooms      int64
# Bathrooms     int64
# Floors        int64
# YearBuilt     int64
# Location     object
# Condition    object
# Garage       object
# Price         int64
# dtype: object

# %% [markdown]
# #Describe

# %%
df.describe()
# Out:
#                 Id         Area     Bedrooms   Bathrooms       Floors  \
# count  2000.000000  2000.000000  2000.000000  2000.00000  2000.000000
# mean   1000.500000  2786.209500     3.003500     2.55250     1.993500
# std     577.494589  1295.146799     1.424606     1.10899     0.809188
# min       1.000000   501.000000     1.000000     1.00000     1.000000
# 25%     500.750000  1653.000000     2.000000     2.00000     1.000000
# 50%    1000.500000  2833.000000     3.000000     3.00000     2.000000
# 75%    1500.250000  3887.500000     4.000000     4.00000     3.000000
# max    2000.000000  4999.000000     5.000000     4.00000     3.000000
#
#          YearBuilt          Price
# count  2000.000000    2000.000000
# mean   1961.446000  537676.855000
# std      35.926695  276428.845719
# min    1900.000000   50005.000000
# 25%    1930.000000  300098.000000
# 50%    1961.000000  539254.000000
# 75%    1993.000000  780086.000000
# max    2023.000000  999656.000000

# %% [markdown]
# #Location

# %%
df.loc[0]
# Out:
# Id                   1
# Area              1360
# Bedrooms             5
# Bathrooms            4
# Floors               3
# YearBuilt         1970
# Location      Downtown
# Condition    Excellent
# Garage              No
# Price           149919
# Name: 0, dtype: object

# %%
#

# %%
df.iloc[0]
# Out:
# Id                   1
# Area              1360
# Bedrooms             5
# Bathrooms            4
# Floors               3
# YearBuilt         1970
# Location      Downtown
# Condition    Excellent
# Garage              No
# Price           149919
# Name: 0, dtype: object

# %%
df.isnull()
# Out:
#          Id   Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  \
# 0     False  False     False      False   False      False     False
# 1     False  False     False      False   False      False     False
# 2     False  False     False      False   False      False     False
# 3     False  False     False      False   False      False     False
# 4     False  False     False      False   False      False     False
# ...     ...    ...       ...        ...     ...        ...       ...
# 1995  False  False     False      False   False      False     False
# 1996  False  False     False      False   False      False     False
# 1997  False  False     False      False   False      False     False
# 1998  False  False     False      False   False      False     False
# 1999  False  False     False      False   False      False     False
#
#       Condition  Garage  Price
# 0         False   False  False
# 1         False   False  False
# 2         False   False  False
# ...

# %%
df.isnull().sum()
# Out:
# Id           0
# Area         0
# Bedrooms     0
# Bathrooms    0
# Floors       0
# YearBuilt    0
# Location     0
# Condition    0
# Garage       0
# Price        0
# dtype: int64

# %%
df["Condition"].unique()
# Out:
# array(['Excellent', 'Good', 'Fair', 'Poor'], dtype=object)

# %%
df["Condition"].nunique()
# Out:
# 4

# %%
df["Location"].value_counts()
# Out:
# Location
# Downtown    558
# Urban       485
# Suburban    483
# Rural       474
# Name: count, dtype: int64

# %%
df["Location"].value_counts().sort_values()
# Out:
# Location
# Rural       474
# Suburban    483
# Urban       485
# Downtown    558
# Name: count, dtype: int64

# %%
df["Location"].value_counts().sort_values(ascending =False)
# Out:
# Location
# Downtown    558
# Urban       485
# Suburban    483
# Rural       474
# Name: count, dtype: int64

# %%
df.sort_values("Location")
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0        1  1360         5          4       3       1970  Downtown  Excellent
# 1337  1338  3593         2          2       3       1951  Downtown       Fair
# 494    495  4768         4          4       2       1986  Downtown       Fair
# 496    497  4209         1          4       2       2020  Downtown       Poor
# 1330  1331  1386         3          3       1       1938  Downtown       Good
# ...    ...   ...       ...        ...     ...        ...       ...        ...
# 1122  1123  4997         2          2       2       1918     Urban  Excellent
# 650    651  3093         1          4       1       1906     Urban       Poor
# 1120  1121  1434         1          4       1       2003     Urban       Good
# 1573  1574  1468         2          2       1       1974     Urban  Excellent
# 833    834  3728         5          1       3       2007     Urban       Poor
#
#      Garage   Price
# ...

# %%
df.sort_values(["Location","Floors"])
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 9       10  2185         3          3       1       2000  Downtown       Poor
# 17      18   974         2          2       1       1919  Downtown       Poor
# 21      22  3247         4          3       1       1931  Downtown  Excellent
# 22      23  1475         3          1       1       1927  Downtown       Poor
# 27      28  2399         2          4       1       1934  Downtown  Excellent
# ...    ...   ...       ...        ...     ...        ...       ...        ...
# 1971  1972  3349         1          3       3       1900     Urban  Excellent
# 1982  1983  4682         3          3       3       1961     Urban  Excellent
# 1986  1987  3211         4          3       3       1965     Urban       Good
# 1987  1988  3588         4          1       3       1929     Urban       Poor
# 1992  1993  2450         1          3       3       2006     Urban       Good
#
#      Garage   Price
# ...

# %%
df.drop_duplicates(subset=["Location"])
# Out:
#    Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0   1  1360         5          4       3       1970  Downtown  Excellent
# 3   4   966         4          2       2       1902  Suburban       Fair
# 5   6  3944         1          2       1       1906     Urban       Poor
# 6   7  3671         1          1       2       1948     Rural       Poor
#
#   Garage   Price
# 0     No  149919
# 3    Yes  244020
# 5     No   93262
# 6    Yes  448722

# %%
df.rename (columns={"YearBuilt" : "Year"})
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  Year  Location  Condition  \
# 0        1  1360         5          4       3  1970  Downtown  Excellent
# 1        2  4272         5          4       3  1958  Downtown  Excellent
# 2        3  3592         2          2       3  1938  Downtown       Good
# 3        4   966         4          2       2  1902  Suburban       Fair
# 4        5  4926         1          4       2  1975  Downtown       Fair
# ...    ...   ...       ...        ...     ...   ...       ...        ...
# 1995  1996  4994         5          4       3  1923  Suburban       Poor
# 1996  1997  3046         5          2       1  2019  Suburban       Poor
# 1997  1998  1062         5          1       2  1903     Rural       Poor
# 1998  1999  4062         3          1       2  1936     Urban  Excellent
# 1999  2000  2989         5          1       3  1903  Suburban       Fair
#
#      Garage   Price
# 0        No  149919
# 1        No  424998
# 2        No  266746
# ...

# %%
df.rename (index= {0:"first_entry" ,1 :"second_entry"})
# Out:
#                 Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  \
# first_entry      1  1360         5          4       3       1970  Downtown
# second_entry     2  4272         5          4       3       1958  Downtown
# 2                3  3592         2          2       3       1938  Downtown
# 3                4   966         4          2       2       1902  Suburban
# 4                5  4926         1          4       2       1975  Downtown
# ...            ...   ...       ...        ...     ...        ...       ...
# 1995          1996  4994         5          4       3       1923  Suburban
# 1996          1997  3046         5          2       1       2019  Suburban
# 1997          1998  1062         5          1       2       1903     Rural
# 1998          1999  4062         3          1       2       1936     Urban
# 1999          2000  2989         5          1       3       1903  Suburban
#
#               Condition Garage   Price
# ...

# %%
Locations = df.groupby("Location")

# %%
Locations

# %%
len(df)
# Out:
# 2000

# %%
len(Locations)
# Out:
# 4

# %%
Locations.size()
# Out:
# Location
# Downtown    558
# Rural       474
# Suburban    483
# Urban       485
# dtype: int64

# %%
Locations.first()
# Out:
#           Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Condition Garage  \
# Location
# Downtown   1  1360         5          4       3       1970  Excellent     No
# Rural      7  3671         1          1       2       1948       Poor    Yes
# Suburban   4   966         4          2       2       1902       Fair    Yes
# Urban      6  3944         1          2       1       1906       Poor     No
#
#            Price
# Location
# Downtown  149919
# Rural     448722
# Suburban  244020
# Urban      93262

# %%
df1 = pd.read_csv(r"C:\Users\Dell Latitude 5480\Downloads\patients.csv")

# %%
df1
# Out:
#      patient_id assigned_sex given_name      surname  \
# 0             1       female        Zoe      Wellish
# 1             2       female     Pamela         Hill
# 2             3         male        Jae       Debord
# 3             4         male       Liêm         Phan
# 4             5         male        Tim      Neudorf
# ..          ...          ...        ...          ...
# 498         499         male    Mustafa    Lindström
# 499         500         male      Ruman      Bisliev
# 500         501       female      Jinke    de Keizer
# 501         502       female    Chidalu  Onyekaozulu
# 502         503         male        Pat      Gersten
#
#                        address               city       state  zip_code  \
# 0         576 Brown Bear Drive  Rancho California  California   92390.0
# 1    2370 University Hill Road          Armstrong    Illinois   61812.0
# 2        1493 Poling Farm Road               York    Nebraska   68467.0
# ...

# %%
df2 = pd.read_csv(r"C:\Users\Dell Latitude 5480\Downloads\treatments_cut.csv")

# %%
df2
# Out:
#    given_name     surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0       jožka   resanovič  22u - 30u          -         7.56       7.22
# 1   inunnguaq    heilmann  57u - 67u          -         7.85       7.45
# 2       alwin    svensson  36u - 39u          -         7.78       7.34
# 3         thể       lương          -  61u - 64u         7.64       7.22
# 4      amanda     ribeiro  36u - 44u          -         7.85       7.47
# ..        ...         ...        ...        ...          ...        ...
# 65     rovzan     kishiev  32u - 37u          -         7.75       7.41
# 66      jakob    jakobsen          -  28u - 26u         7.96       7.51
# 67      bernd   schneider  48u - 56u          -         7.74       7.44
# 68      berta  napolitani          -  42u - 44u         7.68       7.21
# 69     armina       sauvé  36u - 46u          -         7.86       7.40
#
#     hba1c_change
# 0           0.34
# 1            NaN
# 2            NaN
# 3           0.92
# ...

# %%
df.join(df1)
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0        1  1360         5          4       3       1970  Downtown  Excellent
# 1        2  4272         5          4       3       1958  Downtown  Excellent
# 2        3  3592         2          2       3       1938  Downtown       Good
# 3        4   966         4          2       2       1902  Suburban       Fair
# 4        5  4926         1          4       2       1975  Downtown       Fair
# ...    ...   ...       ...        ...     ...        ...       ...        ...
# 1995  1996  4994         5          4       3       1923  Suburban       Poor
# 1996  1997  3046         5          2       1       2019  Suburban       Poor
# 1997  1998  1062         5          1       2       1903     Rural       Poor
# 1998  1999  4062         3          1       2       1936     Urban  Excellent
# 1999  2000  2989         5          1       3       1903  Suburban       Fair
#
# ...

# %%
pd.concat([df,df1])
# Out:
#       Id    Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0    1.0  1360.0       5.0        4.0     3.0     1970.0  Downtown  Excellent
# 1    2.0  4272.0       5.0        4.0     3.0     1958.0  Downtown  Excellent
# 2    3.0  3592.0       2.0        2.0     3.0     1938.0  Downtown       Good
# 3    4.0   966.0       4.0        2.0     2.0     1902.0  Suburban       Fair
# 4    5.0  4926.0       1.0        4.0     2.0     1975.0  Downtown       Fair
# ..   ...     ...       ...        ...     ...        ...       ...        ...
# 498  NaN     NaN       NaN        NaN     NaN        NaN       NaN        NaN
# 499  NaN     NaN       NaN        NaN     NaN        NaN       NaN        NaN
# 500  NaN     NaN       NaN        NaN     NaN        NaN       NaN        NaN
# 501  NaN     NaN       NaN        NaN     NaN        NaN       NaN        NaN
# 502  NaN     NaN       NaN        NaN     NaN        NaN       NaN        NaN
#
# ...
