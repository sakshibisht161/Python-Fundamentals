# %% [markdown]
# # Tuple are used to store multiple items is a single variables .
# #A tuble is a collection which is ordered and unchangeable .
# #Tuple items are ordered,unchangeable ,and allow duplicate values .
# #Tuple items are indexed,the first item has index(0),the second item has index (1) etc.

# %%
T1 = (1,2,3,4,5)
print(T1)
# Out:
# (1, 2, 3, 4, 5)

# %%
print(type(T1))
# Out:
# <class 'tuple'>

# %%
print(len(T1))
# Out:
# 5

# %%
T2=("A","B","C","D")
print(T2)
# Out:
# ('A', 'B', 'C', 'D')

# %%
T2[3]
# Out:
# 'D'

# %%
T2[1]
# Out:
# 'B'

# %%
T2[2:3]
# Out:
# ('C',)

# %%
T2[:4]
# Out:
# ('A', 'B', 'C', 'D')

# %%
T2[-4:-1]
# Out:
# ('A', 'B', 'C')

# %%
T2[-3:]
# Out:
# ('B', 'C', 'D')

# %% [markdown]
# #Create tuble in one item .

# %%
T11=('A')
print(T11)
print(type(T11))
# Out:
# A
# <class 'str'>

# %%
T12=('S',)
print(T12)
print(type(T12))
# Out:
# ('S',)
# <class 'tuple'>

# %%
Sports=("Cricket","Tennis","Football","Hockey")
print(Sports)
print(type(Sports))
# Out:
# ('Cricket', 'Tennis', 'Football', 'Hockey')
# <class 'tuple'>

# %%
Sports[3]
# Out:
# 'Hockey'

# %%
Sports[1:4]
# Out:
# ('Tennis', 'Football', 'Hockey')

# %%
Sports[-4:-1]
# Out:
# ('Cricket', 'Tennis', 'Football')

# %%
Sports[-3]
# Out:
# 'Tennis'

# %%
tup=(12,14,16,18,20)
Y1=list(tup)
Y1[1]=10
tup=tuple(Y1)
print(tup)
# Out:
# (12, 10, 16, 18, 20)

# %%
X=(2,3,4,5,6)
Z1=list(X)
Z1[3]=8
X=tuple(Z1)
print(X)
# Out:
# (2, 3, 4, 8, 6)

# %% [markdown]
# #Addtion of elements

# %%
Y=(2,3,4,5)
Y=Y+(4,)
print(Y)
# Out:
# (2, 3, 4, 5, 4)

# %%
Z1.append(6)
print(Z1)
# Out:
# [2, 3, 4, 8, 6, 6]

# %% [markdown]
# #Addition of tuples

# %%
tuple_add1=(7,)
tuple_add2=(5,6,7,8,9)
tuple_add1=tuple_add1+tuple_add2
print(tuple_add1)
# Out:
# (7, 5, 6, 7, 8, 9)

# %%
A=(10,)
B=(20,30,40,50)
A=A+B
print(A)
# Out:
# (10, 20, 30, 40, 50)

# %%
C=A+B
print(C)
# Out:
# (10, 20, 30, 40, 50, 20, 30, 40, 50)

# %% [markdown]
# #Remove items in tuple

# %%
X=(2,3,4,5,6)
Z1=list(X)
Z1[3]=8
X=tuple(Z1)
print(X)
# Out:
# (2, 3, 4, 8, 6)

# %%
X=list(Z1)
print(Z1)
# Out:
# [2, 3, 4, 8, 6]

# %%
Z1.remove(4)
print(Z1)
# Out:
# [2, 3, 8, 6]

# %% [markdown]
# #Reverse elements
# #t2[start:end:-1(step)]

# %%
t1=(1,2,3,4,5)
t1[::-1]
# Out:
# (5, 4, 3, 2, 1)

# %%
t1[::-2]
# Out:
# (5, 3, 1)

# %%
t1[::-3]
# Out:
# (5, 2)

# %%
t1[::-4]
# Out:
# (5, 1)
