# %% [markdown]
# # Superstore Sales Data

# %% [markdown]
# # Import All Library

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # Import Data

# %%
df =pd.read_csv(r"C:\Users\Dell Latitude 5480\Downloads\archive (7).zip")

# %%
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %% [markdown]
# # Displaying first 4 records

# %%
df.head(4)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# 0      42420.0  South  FUR-BO-10001798        Furniture    Bookcases
# ...

# %% [markdown]
# # Displaying last 4 records

# %%
df.tail(5)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country     City  \
# 9795    SH-19975     Sally Hughsby  Corporate  United States  Chicago
# 9796    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9797    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9798    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9799    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
#
#          State  Postal Code   Region       Product ID         Category  \
# ...

# %% [markdown]
# # Displaying Sample 4 records

# %%
df.sample(4)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 674      675  CA-2018-130351  05/12/2018  08/12/2018     First Class
# 7722    7723  US-2018-138086  16/04/2018  20/04/2018  Standard Class
# 312      313  CA-2017-142902  12/09/2017  14/09/2017    Second Class
# 2503    2504  CA-2017-149482  14/11/2017  19/11/2017  Standard Class
#
#      Customer ID Customer Name      Segment        Country           City  \
# 674     RB-19570   Rob Beeghly     Consumer  United States       Columbus
# 7722    JO-15550  Jesus Ocampo  Home Office  United States  San Francisco
# 312     BP-11185  Ben Peterman    Corporate  United States         Arvada
# 2503    RR-19315  Ralph Ritter     Consumer  United States  San Francisco
#
#            State  Postal Code   Region       Product ID         Category  \
# 674      Indiana      47201.0  Central  OFF-PA-10002137  Office Supplies
# 7722  California      94109.0     West  OFF-AP-10000027  Office Supplies
# ...

# %% [markdown]
# # Checking no of Rows & columns in dataset

# %%
df.shape
# Out:
# (9800, 18)

# %% [markdown]
# # Checking all information of Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %% [markdown]
# # Statistical Summary of Data

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %% [markdown]
# # Checking Null values

# %%
df.isnull()
# Out:
#       Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0      False     False       False      False      False        False
# 1      False     False       False      False      False        False
# 2      False     False       False      False      False        False
# 3      False     False       False      False      False        False
# 4      False     False       False      False      False        False
# ...      ...       ...         ...        ...        ...          ...
# 9795   False     False       False      False      False        False
# 9796   False     False       False      False      False        False
# 9797   False     False       False      False      False        False
# 9798   False     False       False      False      False        False
# 9799   False     False       False      False      False        False
#
#       Customer Name  Segment  Country   City  State  Postal Code  Region  \
# ...

# %% [markdown]
# # Checking Total Null values

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %% [markdown]
# # Transpose of Statistical summary of data

# %%
df.describe().T
# Out:
#               count          mean           std       min        25%  \
# Row ID       9800.0   4900.500000   2829.160653     1.000   2450.750
# Postal Code  9789.0  55273.322403  32041.223413  1040.000  23223.000
# Sales        9800.0    230.769059    626.651875     0.444     17.248
#
#                   50%        75%       max
# Row ID        4900.50   7350.250   9800.00
# Postal Code  58103.00  90008.000  99301.00
# Sales           54.49    210.605  22638.48

# %% [markdown]
# # Checking every elements of total count in a column

# %%
df["Ship Mode"].value_counts()
# Out:
# Ship Mode
# Standard Class    5859
# Second Class      1902
# First Class       1501
# Same Day           538
# Name: count, dtype: int64

# %% [markdown]
# # Sorting every elements of total count in a column

# %%
df["Ship Mode"].value_counts().sort_values()
# Out:
# Ship Mode
# Same Day           538
# First Class       1501
# Second Class      1902
# Standard Class    5859
# Name: count, dtype: int64

# %% [markdown]
# # Descending order sorting

# %%
df["Ship Mode"].value_counts().sort_values(ascending = False)
# Out:
# Ship Mode
# Standard Class    5859
# Second Class      1902
# First Class       1501
# Same Day           538
# Name: count, dtype: int64

# %% [markdown]
# # Sorting every elements based on Segment column

# %%
df.sort_values("Segment")
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 5414    5415  US-2018-125647  23/09/2018  28/09/2018  Standard Class
# 5413    5414  CA-2017-153157  11/09/2017  14/09/2017     First Class
# 5412    5413  CA-2018-166856  18/09/2018  22/09/2018  Standard Class
# 5411    5412  CA-2018-166856  18/09/2018  22/09/2018  Standard Class
# ...      ...             ...         ...         ...             ...
# 5963    5964  CA-2015-140732  11/11/2015  13/11/2015    Second Class
# 5962    5963  CA-2015-140732  11/11/2015  13/11/2015    Second Class
# 5961    5962  CA-2015-140732  11/11/2015  13/11/2015    Second Class
# 5973    5974  CA-2016-143980  25/12/2016  29/12/2016  Standard Class
# 4727    4728  CA-2015-119151  25/11/2015  29/11/2015    Second Class
#
#      Customer ID   Customer Name      Segment        Country           City  \
# ...

# %% [markdown]
# # Sorting every elements based on segment and region column

# %%
df.sort_values(["Segment","Region"])
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 16        17  CA-2015-105893  11/11/2015  18/11/2015  Standard Class
# 46        47  CA-2015-146703  20/10/2015  25/10/2015    Second Class
# 49        50  CA-2016-115742  18/04/2016  22/04/2016  Standard Class
# 50        51  CA-2016-115742  18/04/2016  22/04/2016  Standard Class
# 51        52  CA-2016-115742  18/04/2016  22/04/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9662    9663  CA-2017-160717  06/06/2017  11/06/2017  Standard Class
# 9693    9694  CA-2018-130148  24/09/2018  28/09/2018    Second Class
# 9694    9695  CA-2018-130148  24/09/2018  28/09/2018    Second Class
# 9752    9753  US-2017-158680  01/07/2017  02/07/2017     First Class
# 9768    9769  CA-2018-142328  07/12/2018  14/12/2018  Standard Class
#
#      Customer ID      Customer Name      Segment        Country  \
# 16      PK-19075          Pete Kriz     Consumer  United States
# ...

# %% [markdown]
# # unique values show

# %%
df["Category"].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %% [markdown]
# # show unique values number

# %%
df["Category"].nunique()
# Out:
# 3

# %% [markdown]
# # Checking duplicate values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Checking for group by values

# %%
Regions = df.groupby("Region")
Regions

# %%
len(df)
# Out:
# 9800

# %%
len("Regions")
# Out:
# 7

# %%
Regions.size()
# Out:
# Region
# Central    2277
# East       2785
# South      1598
# West       3140
# dtype: int64

# %%
Regions.first()
# Out:
#          Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# Region
# Central      15  US-2016-118983  22/11/2016  26/11/2016  Standard Class
# East         24  US-2018-156909  16/07/2018  18/07/2018    Second Class
# South         1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# West          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
#
#         Customer ID    Customer Name      Segment        Country  \
# Region
# Central    HP-14815    Harold Pawlan  Home Office  United States
# East       SF-20065  Sandra Flanagan     Consumer  United States
# South      CG-12520      Claire Gute     Consumer  United States
# West       DV-13045  Darrin Van Huff    Corporate  United States
#
#                  City         State  Postal Code       Product ID  \
# Region
# Central    Fort Worth         Texas      76106.0  OFF-AP-10002311
# East     Philadelphia  Pennsylvania      19140.0  FUR-CH-10002774
# ...

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # Bar Chart

# %%
df["Segment"].value_counts().plot(kind = "bar",color = "g")
# Out:
# <Axes: xlabel='Segment'>

# %%
df["Sub-Category"].value_counts().plot(kind = "bar" , color = "y")
# Out:
# <Axes: xlabel='Sub-Category'>

# %% [markdown]
# # Pie Chart

# %%
df["Ship Mode"].value_counts().plot(kind = "pie")
# Out:
# <Axes: ylabel='count'>

# %%
df["Ship Mode"].value_counts().plot(kind = "pie" , autopct = "%1.1f%%" , title =" Ship Mode distribution")
plt.ylabel(' ')
plt.show()

# %% [markdown]
# # Count Plot

# %%
sns.countplot(x = "Region" , data = df , palette = "Set2")
# Out:
# C:\Users\Dell Latitude 5480\AppData\Local\Temp\ipykernel_3984\889801299.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = "Region" , data = df , palette = "Set2")
# <Axes: xlabel='Region', ylabel='count'>

# %% [markdown]
# # displot

# %%
sns.displot(x = "Ship Mode" , data = df , hue = "Ship Mode")

# %% [markdown]
# # Histplot

# %%
sns.barplot( x = "Sub Cate" , data = df , kde = True , color ="m")
# Out:
# <Axes: xlabel='Segment', ylabel='Count'>

# %%
sns.scatterplot(x = "Segment" , y ="Sales" , data = df )
# Out:
# <Axes: xlabel='Segment', ylabel='Sales'>

# %% [markdown]
# # Pair plot

# %%
sns.pairplot(df,hue="Region")
