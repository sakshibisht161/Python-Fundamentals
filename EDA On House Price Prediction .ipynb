# %% [markdown]
# # House Price Pridiction

# %% [markdown]
# # Import All Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # Import Data

# %%
df = pd.read_csv(r"C:\Users\Dell Latitude 5480\Downloads\archive (3).zip")

# %%
df
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0        1  1360         5          4       3       1970  Downtown  Excellent
# 1        2  4272         5          4       3       1958  Downtown  Excellent
# 2        3  3592         2          2       3       1938  Downtown       Good
# 3        4   966         4          2       2       1902  Suburban       Fair
# 4        5  4926         1          4       2       1975  Downtown       Fair
# ...    ...   ...       ...        ...     ...        ...       ...        ...
# 1995  1996  4994         5          4       3       1923  Suburban       Poor
# 1996  1997  3046         5          2       1       2019  Suburban       Poor
# 1997  1998  1062         5          1       2       1903     Rural       Poor
# 1998  1999  4062         3          1       2       1936     Urban  Excellent
# 1999  2000  2989         5          1       3       1903  Suburban       Fair
#
#      Garage   Price
# ...

# %% [markdown]
# # Displaying first 5 records

# %%
df.head(5)
# Out:
#    Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0   1  1360         5          4       3       1970  Downtown  Excellent
# 1   2  4272         5          4       3       1958  Downtown  Excellent
# 2   3  3592         2          2       3       1938  Downtown       Good
# 3   4   966         4          2       2       1902  Suburban       Fair
# 4   5  4926         1          4       2       1975  Downtown       Fair
#
#   Garage   Price
# 0     No  149919
# 1     No  424998
# 2     No  266746
# 3    Yes  244020
# 4    Yes  636056

# %% [markdown]
# # Displaying last 5 records

# %%
df.tail(5)
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 1995  1996  4994         5          4       3       1923  Suburban       Poor
# 1996  1997  3046         5          2       1       2019  Suburban       Poor
# 1997  1998  1062         5          1       2       1903     Rural       Poor
# 1998  1999  4062         3          1       2       1936     Urban  Excellent
# 1999  2000  2989         5          1       3       1903  Suburban       Fair
#
#      Garage   Price
# 1995     No  295620
# 1996    Yes  580929
# 1997     No  476925
# 1998    Yes  161119
# 1999     No  482525

# %% [markdown]
# # Displaying Random 5 records

# %%
df.sample(5)
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 719    720   742         1          2       3       1979     Urban  Excellent
# 1591  1592  4812         2          1       2       1938     Urban  Excellent
# 578    579  3224         1          4       2       1904     Urban       Fair
# 491    492  4102         3          3       1       1917     Rural  Excellent
# 461    462  1453         4          3       1       1941  Suburban  Excellent
#
#      Garage   Price
# 719     Yes  830343
# 1591     No  450717
# 578     Yes  515996
# 491     Yes  314826
# 461     Yes  972879

# %% [markdown]
# # Checking no of Rows & columns in dataset

# %%
df.shape
# Out:
# (2000, 10)

# %% [markdown]
# # Checking all information of Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Id         2000 non-null   int64
#  1   Area       2000 non-null   int64
#  2   Bedrooms   2000 non-null   int64
#  3   Bathrooms  2000 non-null   int64
#  4   Floors     2000 non-null   int64
#  5   YearBuilt  2000 non-null   int64
#  6   Location   2000 non-null   object
#  7   Condition  2000 non-null   object
#  8   Garage     2000 non-null   object
#  9   Price      2000 non-null   int64
# dtypes: int64(7), object(3)
# memory usage: 156.4+ KB

# %% [markdown]
# # Statistical Summary of Data

# %%
df.describe()
# Out:
#                 Id         Area     Bedrooms   Bathrooms       Floors  \
# count  2000.000000  2000.000000  2000.000000  2000.00000  2000.000000
# mean   1000.500000  2786.209500     3.003500     2.55250     1.993500
# std     577.494589  1295.146799     1.424606     1.10899     0.809188
# min       1.000000   501.000000     1.000000     1.00000     1.000000
# 25%     500.750000  1653.000000     2.000000     2.00000     1.000000
# 50%    1000.500000  2833.000000     3.000000     3.00000     2.000000
# 75%    1500.250000  3887.500000     4.000000     4.00000     3.000000
# max    2000.000000  4999.000000     5.000000     4.00000     3.000000
#
#          YearBuilt          Price
# count  2000.000000    2000.000000
# mean   1961.446000  537676.855000
# std      35.926695  276428.845719
# min    1900.000000   50005.000000
# 25%    1930.000000  300098.000000
# 50%    1961.000000  539254.000000
# 75%    1993.000000  780086.000000
# max    2023.000000  999656.000000

# %% [markdown]
# # Checking Null values

# %%
df.isnull()
# Out:
#          Id   Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  \
# 0     False  False     False      False   False      False     False
# 1     False  False     False      False   False      False     False
# 2     False  False     False      False   False      False     False
# 3     False  False     False      False   False      False     False
# 4     False  False     False      False   False      False     False
# ...     ...    ...       ...        ...     ...        ...       ...
# 1995  False  False     False      False   False      False     False
# 1996  False  False     False      False   False      False     False
# 1997  False  False     False      False   False      False     False
# 1998  False  False     False      False   False      False     False
# 1999  False  False     False      False   False      False     False
#
#       Condition  Garage  Price
# 0         False   False  False
# 1         False   False  False
# 2         False   False  False
# ...

# %% [markdown]
# # Checking Total Null values

# %%
df.isnull().sum()
# Out:
# Id           0
# Area         0
# Bedrooms     0
# Bathrooms    0
# Floors       0
# YearBuilt    0
# Location     0
# Condition    0
# Garage       0
# Price        0
# dtype: int64

# %% [markdown]
# # Transpose of Statistical summary of data

# %%
df.describe().T
# Out:
#             count         mean            std      min        25%       50%  \
# Id         2000.0    1000.5000     577.494589      1.0     500.75    1000.5
# Area       2000.0    2786.2095    1295.146799    501.0    1653.00    2833.0
# Bedrooms   2000.0       3.0035       1.424606      1.0       2.00       3.0
# Bathrooms  2000.0       2.5525       1.108990      1.0       2.00       3.0
# Floors     2000.0       1.9935       0.809188      1.0       1.00       2.0
# YearBuilt  2000.0    1961.4460      35.926695   1900.0    1930.00    1961.0
# Price      2000.0  537676.8550  276428.845719  50005.0  300098.00  539254.0
#
#                  75%       max
# Id           1500.25    2000.0
# Area         3887.50    4999.0
# Bedrooms        4.00       5.0
# Bathrooms       4.00       4.0
# Floors          3.00       3.0
# YearBuilt    1993.00    2023.0
# Price      780086.00  999656.0

# %% [markdown]
# # Checking every elements of total count in a column

# %%
df["Location"].value_counts()
# Out:
# Location
# Downtown    558
# Urban       485
# Suburban    483
# Rural       474
# Name: count, dtype: int64

# %% [markdown]
# # Sorting every elements of total count in a column

# %%
df["Location"].value_counts().sort_values()
# Out:
# Location
# Rural       474
# Suburban    483
# Urban       485
# Downtown    558
# Name: count, dtype: int64

# %% [markdown]
# # Descending order sorting

# %%
df["Location"].value_counts().sort_values(ascending = False)
# Out:
# Location
# Downtown    558
# Urban       485
# Suburban    483
# Rural       474
# Name: count, dtype: int64

# %% [markdown]
# # Sorting every elements based on Condition column

# %%
df.sort_values("Condition")
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0        1  1360         5          4       3       1970  Downtown  Excellent
# 1324  1325  4053         2          3       1       1970  Suburban  Excellent
# 1317  1318   528         3          4       3       1927     Rural  Excellent
# 479    480  1010         3          3       2       1925     Urban  Excellent
# 480    481  4812         3          2       1       1928  Downtown  Excellent
# ...    ...   ...       ...        ...     ...        ...       ...        ...
# 1570  1571  2439         3          3       1       1911  Suburban       Poor
# 294    295  3450         2          4       3       1982     Rural       Poor
# 617    618   637         3          3       2       2008  Suburban       Poor
# 1579  1580  4793         2          1       3       1901     Urban       Poor
# 999   1000  3268         1          2       2       1962     Rural       Poor
#
#      Garage   Price
# ...

# %% [markdown]
# # Sorting every elements based on Condition and Garage column

# %%
df.sort_values(["Condition","Garage"])
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0        1  1360         5          4       3       1970  Downtown  Excellent
# 1        2  4272         5          4       3       1958  Downtown  Excellent
# 19      20  3058         5          2       2       2016  Downtown  Excellent
# 21      22  3247         4          3       1       1931  Downtown  Excellent
# 29      30  2028         2          4       1       1929  Downtown  Excellent
# ...    ...   ...       ...        ...     ...        ...       ...        ...
# 1970  1971  1214         2          4       1       1915     Rural       Poor
# 1978  1979  2648         4          4       3       1980  Suburban       Poor
# 1983  1984  3956         4          4       1       1971     Urban       Poor
# 1991  1992  4397         4          1       2       1981     Rural       Poor
# 1996  1997  3046         5          2       1       2019  Suburban       Poor
#
#      Garage   Price
# ...

# %% [markdown]
# # unique values show

# %%
df["Location"].unique()
# Out:
# array(['Downtown', 'Suburban', 'Urban', 'Rural'], dtype=object)

# %% [markdown]
# # show unique values number

# %%
df["Location"].nunique()
# Out:
# 4

# %% [markdown]
# # Checking duplicate values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Checking for group by values

# %%
Conditions = df.groupby("Condition")
Conditions

# %%
len(df)
# Out:
# 2000

# %%
len("Conditions")
# Out:
# 10

# %%
Conditions.size()
# Out:
# Condition
# Excellent    511
# Fair         521
# Good         461
# Poor         507
# dtype: int64

# %%
Conditions.first()
# Out:
#            Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location Garage  \
# Condition
# Excellent   1  1360         5          4       3       1970  Downtown     No
# Fair        4   966         4          2       2       1902  Suburban    Yes
# Good        3  3592         2          2       3       1938  Downtown     No
# Poor        6  3944         1          2       1       1906     Urban     No
#
#             Price
# Condition
# Excellent  149919
# Fair       244020
# Good       266746
# Poor        93262

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # Bar chart

# %%
df["Location"].value_counts().plot(kind = "bar" , color ="r")
# Out:
# <Axes: xlabel='Location'>

# %% [markdown]
# # Pie chart

# %%
df["Garage"].value_counts().plot(kind = "pie")
# Out:
# <Axes: ylabel='count'>

# %%
df["Garage"].value_counts().plot(kind = "pie", autopct = "%1.1f%%" , title = "Garage distribution")
plt.ylabel(' ')
plt.show()

# %% [markdown]
# # Count plot

# %%
sns.countplot(x ="Condition" , data = df , palette = "Set2")
# Out:
# C:\Users\Dell Latitude 5480\AppData\Local\Temp\ipykernel_5920\2742766820.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x ="Condition" , data = df , palette = "Set2")
# <Axes: xlabel='Condition', ylabel='count'>

# %% [markdown]
# # Displot

# %%
sns.displot( x = "Location" , data = df ,color="darkorange")

# %% [markdown]
# # Histplot

# %%
sns.histplot(x = "Bedrooms" , data = df ,kde = True , color ="m")
# Out:
# <Axes: xlabel='Bedrooms', ylabel='Count'>

# %% [markdown]
# # Scatter plot

# %%
sns.scatterplot (x = "Floors" , y = "Bathrooms" , data = df , hue = "Location")
# Out:
# <Axes: xlabel='Floors', ylabel='Bathrooms'>

# %% [markdown]
# # Boxplot

# %%
sns.boxplot( x = "Condition" ,y = "Bathrooms" , data = df , hue ="Condition" )
# Out:
# <Axes: xlabel='Condition', ylabel='Bathrooms'>

# %%
sns.scatterplot(x ="Condition" ,y = "Floors"

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(df,hue = "Location")
