# %%
print("Hello AAFT")
# Out:
# Hello AAFT

# %%
a="Hello,AAFT"
print(a)
# Out:
# Hello,AAFT

# %%
b="""sid is naughty boy.
yash is not saying anything.
nayanshi is not practicing python."""
print(b)
# Out:
# sid is naughty boy.
# yash is not saying anything.
# nayanshi is not practicing python.

# %%
print(a[1])
# Out:
# e

# %%
print(a[4])
# Out:
# o

# %%
print(len(a))
# Out:
# 10

# %% [markdown]
# #access of elements

# %%
c="hello world"
print(c[2:5])
# Out:
# llo

# %%
print(c[5:9]) #slicing
# Out:
#  wor

# %% [markdown]
# #slicing from start

# %%
x="hello world"
print(x[:5])
# Out:
# hello

# %% [markdown]
# #slicig from end

# %%
x="hello world"
print(x[2:])
# Out:
# llo world

# %% [markdown]
# #negative indexing

# %%
x="hello world"
print(x[-5:-2])
# Out:
# wor

# %% [markdown]
# #string method

# %%
s1="aaft aaft aaft sods"
x=s1.count("aaft")
print(x)
# Out:
# 3

# %%
s1="aaft aaft aaft sods"
x=s1.find("sods")
print(x)
# Out:
# 15

# %%
s1="aaft aaft aaft sods"
x=s1.find("soa")
print(x)
# Out:
# -1

# %%
x="hello world"
print(x.upper())
# Out:
# HELLO WORLD

# %%
x="hello world"
print(x.lower())
# Out:
# hello world

# %%
x=" hello world "
print(x.strip())
# Out:
# hello world

# %%
a="hello"
b="world"
c=a+b
print(c)
# Out:
# helloworld

# %%
a="hello"
b="world"
c=a + " "+ b
print(c)
# Out:
# hello world

# %% [markdown]
# #format string
# # we cannot combine

# %%
print("hello diplomates")
# Out:
# hello diplomates

# %%
X1=("hello python")
print(X1)
# Out:
# hello python

# %%
print(X1[3:8])
# Out:
# lo py

# %%
print(X1[:10])
# Out:
# hello pyth

# %%
print(X1[-10:-2])
# Out:
# llo pyth

# %%
print(X1[-6:])
# Out:
# python

# %%
print(len(X1))
# Out:
# 12

# %%
print(type(X1))
# Out:
# <class 'str'>

# %%
Y1="coding,coding,coding,coding,stats"
x=Y1.count("coding")
print(x)
# Out:
# 4

# %%
Y1="coding,coding,coding,coding,stats"
x=Y1.find("stats")
print(x)
# Out:
# 28

# %%
z="hello python"
print(z.upper())
# Out:
# HELLO PYTHON

# %%
z="hello python"
print(z.lower())
# Out:
# hello python

# %%
z=" hello python "
print(z.strip())
# Out:
# hello python

# %%
a="hello"
b="python"
c=a+b
print(c)
# Out:
# hellopython

# %%
a="hello"
b="python"
c=a + " " + b
print(c)
# Out:
# hello python

# %%
print("hello aaft")
# Out:
# hello aaft

# %%
x="hello aaft"
print(x)
# Out:
# hello aaft

# %%
print(len(x))
# Out:
# 10

# %%
print(type(x))
# Out:
# <class 'str'>

# %%
y="""i am sakshi bisht.
i am from delhi.
i just completed my graduation from delhi university."""
print(y)
# Out:
# i am sakshi bisht.
# i am from delhi.
# i just completed my graduation from delhi university.

# %%
print(x[2:8])
# Out:
# llo aa

# %%
print(x[-7:-1])
# Out:
# lo aaf

# %%
a1="excel ,excel,excel,excel,excel,database"
x=a1.count("excel")
print(x)
# Out:
# 5

# %%
a1="excel ,excel,excel,excel,excel,database"
x=a1.find("database")
print(x)
# Out:
# 31

# %%
z="HELLO NAYANSHI"
print(z.lower())
# Out:
# hello nayanshi

# %%
z="hello nayanshi"
print(z.upper())
# Out:
# HELLO NAYANSHI

# %%
x="power"
y="bi"
z=x+y
print(z)
# Out:
# powerbi

# %%
x="power"
y="bi"
z=x + " " + y
print(z)
# Out:
# power bi

# %% [markdown]
# #we can combine strings and numbers by using the format () method.

# %%
age=22
txt="my name is sakshi,and i am {}"
print(txt.format(age))
# Out:
# my name is sakshi,and i am 22

# %%
age=24
txt="my name is aman , and i am {}"
print(txt.format(age))
# Out:
# my name is aman , and i am 24

# %% [markdown]
# #The format() method takes unlimited number of arguments and are placed into the respective palace.

# %%
quantity=3
itemno=567
price=49.95
myorder="i want {} pieces of item {} for dollars."
print(myorder.format(quantity,itemno,price))
# Out:
# i want 3 pieces of item 567 for dollars.

# %% [markdown]
# # escape character
# #to insert character that are illegal in a string ,using an escape character.
# #an escape character is a backslash \ followeed by the character you want to insert .
# #the escape character allows you to use double quotes when you nornally would not be allowed;

# %%
txt= "we are the so-called \"vikings\" from the north."
print(txt)
# Out:
# we are the so-called "vikings" from the north.

# %% [markdown]
# #capitalized method

# %%
txt="hello , and welcome to my world "
x=txt.capitalize()
print(x)
# Out:
# Hello , and welcome to my world

# %% [markdown]
# # title() method
# # the first character is converted to upper case,and the rest are converted to lower case;

# %%
txt="hello , and welcome to my world "
x=txt.title()
print(x)
# Out:
# Hello , And Welcome To My World

# %%
txt = "i love apples,apple are my favorite fruit"
x=txt.count("apple")
print(x)
# Out:
# 2

# %%
txt = "i love apples,apple are my favorite fruit"
x=txt.count("apple",10,24)
print(x)
# Out:
# 1

# %% [markdown]
# # find () method

# %%
txt="hello , and welcome to my world "
x=txt.find("welcome")
print(x)
# Out:
# 12

# %%
txt="hello , and welcome to my world "
x=txt.find("e",5,10)
print(x)
# Out:
# -1

# %%
txt="hello , and welcome to my world "
x=txt.find("w")
print(x)
# Out:
# 12

# %% [markdown]
# # the index () method

# %%
txt="hello ,and welcome to my world "
x=txt.index("welcome")
print(x)
# Out:
# 11

# %%
txt="hello ,and welcome to my world "
x=txt.index("m")
print(x)
# Out:
# 16

# %% [markdown]
# # join () method

# %%
mytuple=("sakshi","saurabh","aman")
x="#".join(mytuple)
print(x)
# Out:
# sakshi#saurabh#aman

# %% [markdown]
# #replace () method

# %%
txt="i like grapes"
x=txt.replace("grapes","apple")
print(x)
# Out:
# i like apple

# %% [markdown]
# # partition () method

# %%
txt="i could eat grapes all day"
x=txt.partition("apple")
print(x)
# Out:
# ('i could eat grapes all day', '', '')

# %%
txt="i could eat grapes all day"
x=txt.partition("grapes")
print(x)
# Out:
# ('i could eat ', 'grapes', ' all day')

# %% [markdown]
# # split () method

# %%
txt = "welcome to my world"
x=txt.split()
print(x)
# Out:
# ['welcome', 'to', 'my', 'world']

# %%
txt="hello,my name is sakshi,i am 22 years old"
x=txt.split()
print(x)
# Out:
# ['hello,my', 'name', 'is', 'sakshi,i', 'am', '22', 'years', 'old']

# %%
x="hello coding"
print(x)
# Out:
# hello coding

# %%
print(x[3])
# Out:
# l

# %%
print(x[4:8])
# Out:
# o co

# %%
print(x.upper())
# Out:
# HELLO CODING

# %%
x="HELLO CODING"
print(x.lower())
# Out:
# hello coding

# %%
y = "coding,coding,coding,coding,aaft"
print(y.count("coding"))
# Out:
# 4

# %%
y = "coding,coding,coding,coding,aaft"
print(y.find("aaft"))
# Out:
# 28

# %%
print(y.find('d'))
# Out:
# 2

# %%
name=("nayanshi","rishabh")
x="#".join(name)
print(x)
# Out:
# nayanshi#rishabh

# %%
txt="hello , i am sakshi bisht"
print(txt.partition("sakshi"))
# Out:
# ('hello , i am ', 'sakshi', ' bisht')

# %%
print(txt.split("sakshi"))
# Out:
# ['hello , i am ', ' bisht']

# %%
print(txt.replace("bisht","rawat"))
# Out:
# hello , i am sakshi rawat

# %%
print(txt.index("sakshi"))
# Out:
# 13

# %%
age=22
txt="my name is sakshi bisht. and i am {}"
print(txt.format(age))
# Out:
# my name is sakshi bisht. and i am 22

# %%
age = 18 
txt = "my name is sumit bisht , and i am {}"
print(txt.format(age))
# Out:
# my name is sumit bisht , and i am 18
