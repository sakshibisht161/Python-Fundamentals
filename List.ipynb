# %%
#list creation
X = [1,2,3,4,5,6,7,8,9]
print(X)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
#create list type
X = [1,2,3,4,5,6,7,8,9]
print(list(X))
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
# create type
X = [1,2,3,4,5,6,7,8,9]
print(len(X))
# Out:
# 9

# %%
x  = [2,3,4,7]

x2 = len(x)
print(x2)
# Out:
# 4

# %%
list1 =["a","b","c","a","b"]
print(list1)
# Out:
# ['a', 'b', 'c', 'a', 'b']

# %%
list1[0]
# Out:
# 'a'

# %%
list1[1]
# Out:
# 'b'

# %%
list1[2]
# Out:
# 'c'

# %%
list1[3]
# Out:
# 'a'

# %%
list1[4]
# Out:
# 'b'

# %%
list1 =["a","b","c","a","b"]
print(list1)
# Out:
# ['a', 'b', 'c', 'a', 'b']

# %%
list1[1:3]
# Out:
# ['b', 'c']

# %%
list1[3:5]
# Out:
# ['a', 'b']

# %%
list1[2:5]
# Out:
# ['c', 'a', 'b']

# %%
list1[:5]
# Out:
# ['a', 'b', 'c', 'a', 'b']

# %%
list1[0:]
# Out:
# ['a', 'b', 'c', 'a', 'b']

# %%
list2 =["a","b","c","a","b"]
print(list2)
# Out:
# ['a', 'b', 'c', 'a', 'b']

# %%
list2[-4:-1]
# Out:
# ['b', 'c', 'a']

# %%
list2[-3:]
# Out:
# ['c', 'a', 'b']

# %%
list2[:-1]
# Out:
# ['a', 'b', 'c', 'a']

# %%
Diploma = ["Parveen","Sakshi","Nayanshi","Kaif","Danish","Hemant","Sanjeev","Shariq"]
print(Diploma)
# Out:
# ['Parveen', 'Sakshi', 'Nayanshi', 'Kaif', 'Danish', 'Hemant', 'Sanjeev', 'Shariq']

# %%
Diploma[:3]
# Out:
# ['Parveen', 'Sakshi', 'Nayanshi']

# %%
Diploma[3:7]
# Out:
# ['Kaif', 'Danish', 'Hemant', 'Sanjeev']

# %%
Diploma[5:]
# Out:
# ['Hemant', 'Sanjeev', 'Shariq']

# %%
#Change item value 
L2 = [1,2,3,4,5,6,7]
print(L2)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
L2[2]=8
print(L2)
# Out:
# [1, 2, 8, 4, 5, 6, 7]

# %%
L2[1:3]="A","B"
print(L2)
# Out:
# [1, 'A', 'B', 4, 5, 6, 7]

# %%
L2[2]=2
print(L2)
# Out:
# [1, 'A', 2, 4, 5, 6, 7]

# %% [markdown]
# #List item addition
# #Append items
# #List creation

# %%
Course = ["Python","SQL","Stats"]
print(Course)
# Out:
# ['Python', 'SQL', 'Stats']

# %%
Course.append("Excel")
print(Course)
# Out:
# ['Python', 'SQL', 'Stats', 'Excel']

# %% [markdown]
# #Insert items
# #To insert a list item at a specified index,use the insert()method

# %%
Course.insert(3,"Algo")
print(Course)
# Out:
# ['Python', 'SQL', 'Stats', 'Algo', 'Excel']

# %%
Course.insert(2,"BI")
print(Course)
# Out:
# ['Python', 'SQL', 'BI', 'Stats', 'Algo', 'Excel']

# %%
Company = ["TCS","Infosys","Wipro"]
print(Company)
# Out:
# ['TCS', 'Infosys', 'Wipro']

# %% [markdown]
# #Extend List
# #To append elements from another list to the current list,use the extend():

# %%
Course.extend(Company)
print(Course)
# Out:
# ['Python', 'SQL', 'BI', 'Stats', 'Algo', 'Excel', 'TCS', 'Infosys', 'Wipro']

# %%
Sports = ["cricket","football","hockey"]
Sports.append("vollyball")
print(Sports)
# Out:
# ['cricket', 'football', 'hockey', 'vollyball']

# %%
Place=["Mumbai","Delhi","Gurgaon"]
print(Place)
# Out:
# ['Mumbai', 'Delhi', 'Gurgaon']

# %%
Sports.extend(Place)
print(Sports)
# Out:
# ['cricket', 'football', 'hockey', 'vollyball', 'Mumbai', 'Delhi', 'Gurgaon']

# %% [markdown]
# #Remove Specified Item
# #The remove()method removes the specified item.

# %%
Course = ["Python","SQL","Stats"]
Course.remove("Stats")
print(Course)
# Out:
# ['Python', 'SQL']

# %%
Place=["Mumbai","Delhi","Gurgaon"]
Place.remove("Delhi")
print(Place)
# Out:
# ['Mumbai', 'Gurgaon']

# %%
Course.remove("Algo")
print(Course)
# Out:
# ['Python', 'SQL', 'BI', 'Stats', 'Excel', 'TCS', 'Infosys', 'Wipro']

# %% [markdown]
# #Pop Method
# #If do not specify the index ,the pop() method remove thw last time.

# %%
stud=['M','N','O','P','Q','R']
stud.pop()
# Out:
# 'R'

# %%
stud 
['M','N','O','P','Q']

# %%
#Pop () method removes the specified index.
stud.pop(2)
# Out:
# 'O'

# %%
stud.pop(3)
# Out:
# 'Q'

# %%
stud
['M','N''P']

# %% [markdown]
# #Del keyword also removes the specified index

# %%
List1=[10,20,"A",30,40]
del List1[3]
print(List1)
# Out:
# [10, 20, 'A', 40]

# %%
List2=[10,20,"A",40]
del List2[2]
print(List2)
# Out:
# [10, 20, 40]

# %% [markdown]
# #Clear the list
# #Clear () method remove all the elements from  list

# %%
L1=[1,2,3,4]
L1.clear()
print(L1)
# Out:
# []

# %%
L2=[5,6,7,8]
L2.clear()
print(L2)
# Out:
# []

# %% [markdown]
# #Copy list

# %%
Movie =["ABC","RRR","Lagan"]
print(Movie)
# Out:
# ['ABC', 'RRR', 'Lagan']

# %%
Film=Movie.copy()
print(Film)
# Out:
# ['ABC', 'RRR', 'Lagan']

# %% [markdown]
# #Copy list(list method)

# %%
Film2=list(Movie)
print(Film2)
# Out:
# ['ABC', 'RRR', 'Lagan']

# %% [markdown]
# #Join two list

# %%
L11 =[9,8,7,6]
L12 =[1,2,3,4,5]
L13= L11+L12
print(L13)
# Out:
# [9, 8, 7, 6, 1, 2, 3, 4, 5]

# %%
print(max(L11))
# Out:
# 9

# %%
print(min(L12))
# Out:
# 1
