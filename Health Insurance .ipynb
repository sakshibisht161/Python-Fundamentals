# %% [markdown]
# # Health insurance data

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Dell Latitude 5480\Downloads\archive (2).zip")

# %%
df
# Out:
#       age  gender   bmi  children discount_eligibility     region  expenses  \
# 0      19  female  27.9         0                  yes  southwest  16884.92
# 1      18    male  33.8         1                   no  southeast   1725.55
# 2      28    male  33.0         3                   no  southeast   4449.46
# 3      33    male  22.7         0                   no  northwest  21984.47
# 4      32    male  28.9         0                   no  northwest   3866.86
# ...   ...     ...   ...       ...                  ...        ...       ...
# 1333   50    male  31.0         3                   no  northwest  10600.55
# 1334   18  female  31.9         0                   no  northeast   2205.98
# 1335   18  female  36.9         0                   no  southeast   1629.83
# 1336   21  female  25.8         0                   no  southwest   2007.95
# 1337   61  female  29.1         0                  yes  northwest  29141.36
#
#         premium
# 0      168.8492
# 1       17.2555
# ...

# %% [markdown]
# # Displaying first 4 records

# %%
df.head(4)
# Out:
#    age  gender   bmi  children discount_eligibility     region  expenses  \
# 0   19  female  27.9         0                  yes  southwest  16884.92
# 1   18    male  33.8         1                   no  southeast   1725.55
# 2   28    male  33.0         3                   no  southeast   4449.46
# 3   33    male  22.7         0                   no  northwest  21984.47
#
#     premium
# 0  168.8492
# 1   17.2555
# 2   44.4946
# 3  439.6894

# %% [markdown]
# # Displaying last 4 records

# %%
df.tail(4)
# Out:
#       age  gender   bmi  children discount_eligibility     region  expenses  \
# 1334   18  female  31.9         0                   no  northeast   2205.98
# 1335   18  female  36.9         0                   no  southeast   1629.83
# 1336   21  female  25.8         0                   no  southwest   2007.95
# 1337   61  female  29.1         0                  yes  northwest  29141.36
#
#         premium
# 1334    22.0598
# 1335    16.2983
# 1336    20.0795
# 1337  1165.6544

# %% [markdown]
# # Displaying Random 4 records

# %%
df.sample(4)
# Out:
#       age  gender   bmi  children discount_eligibility     region  expenses  \
# 1160   43  female  34.6         1                   no  northwest   7727.25
# 824    60    male  24.3         0                   no  northwest  12523.60
# 5      31  female  25.7         0                   no  southeast   3756.62
# 718    51  female  36.7         2                   no  northwest  10848.13
#
#        premium
# 1160  154.5450
# 824   250.4720
# 5      75.1324
# 718   216.9626

# %% [markdown]
# # Checking no of Rows & columns in dataset

# %%
df.shape
# Out:
# (1338, 8)

# %% [markdown]
# # Checking all information of Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   age                   1338 non-null   int64
#  1   gender                1338 non-null   object
#  2   bmi                   1338 non-null   float64
#  3   children              1338 non-null   int64
#  4   discount_eligibility  1338 non-null   object
#  5   region                1338 non-null   object
#  6   expenses              1338 non-null   float64
#  7   premium               1338 non-null   float64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 83.8+ KB

# %% [markdown]
# # Statistical Summary of Data

# %%
df.describe()
# Out:
#                age          bmi     children      expenses      premium
# count  1338.000000  1338.000000  1338.000000   1338.000000  1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414   262.874685
# std      14.049960     6.098382     1.205493  12110.011240   292.532178
# min      18.000000    16.000000     0.000000   1121.870000    11.218700
# 25%      27.000000    26.300000     0.000000   4740.287500    87.354250
# 50%      39.000000    30.400000     1.000000   9382.030000   174.997400
# 75%      51.000000    34.700000     2.000000  16639.915000   342.908900
# max      64.000000    53.100000     5.000000  63770.430000  1983.106400

# %% [markdown]
# # Checking Null values

# %%
df.isnull()
# Out:
#         age  gender    bmi  children  discount_eligibility  region  expenses  \
# 0     False   False  False     False                 False   False     False
# 1     False   False  False     False                 False   False     False
# 2     False   False  False     False                 False   False     False
# 3     False   False  False     False                 False   False     False
# 4     False   False  False     False                 False   False     False
# ...     ...     ...    ...       ...                   ...     ...       ...
# 1333  False   False  False     False                 False   False     False
# 1334  False   False  False     False                 False   False     False
# 1335  False   False  False     False                 False   False     False
# 1336  False   False  False     False                 False   False     False
# 1337  False   False  False     False                 False   False     False
#
#       premium
# 0       False
# ...

# %% [markdown]
# # Checking Total Null values

# %%
df.isnull().sum()
# Out:
# age                     0
# gender                  0
# bmi                     0
# children                0
# discount_eligibility    0
# region                  0
# expenses                0
# premium                 0
# dtype: int64

# %% [markdown]
# # Transpose of Statistical summary of data

# %%
df.describe().T
# Out:
#            count          mean           std        min         25%  \
# age       1338.0     39.207025     14.049960    18.0000    27.00000
# bmi       1338.0     30.665471      6.098382    16.0000    26.30000
# children  1338.0      1.094918      1.205493     0.0000     0.00000
# expenses  1338.0  13270.422414  12110.011240  1121.8700  4740.28750
# premium   1338.0    262.874685    292.532178    11.2187    87.35425
#
#                 50%         75%         max
# age         39.0000     51.0000     64.0000
# bmi         30.4000     34.7000     53.1000
# children     1.0000      2.0000      5.0000
# expenses  9382.0300  16639.9150  63770.4300
# premium    174.9974    342.9089   1983.1064

# %% [markdown]
# # Checking every elements of total count in a column

# %%
df["region"].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %% [markdown]
# # Sorting every elements of total count in a column

# %%
df["region"].value_counts().sort_values()
# Out:
# region
# northeast    324
# southwest    325
# northwest    325
# southeast    364
# Name: count, dtype: int64

# %% [markdown]
# # Descending order sorting

# %%
df["region"].value_counts().sort_values(ascending = False)
# Out:
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %% [markdown]
# # Sorting every elements based on region column

# %%
df.sort_values("region")
# Out:
#      age  gender   bmi  children discount_eligibility     region  expenses  \
# 668   62    male  32.0         0                  yes  northeast  45710.21
# 319   32    male  37.3         1                   no  northeast   4667.61
# 844   53    male  30.5         0                   no  northeast  10072.06
# 317   54    male  32.8         0                   no  northeast  10435.07
# 315   52    male  33.3         0                   no  northeast   9722.77
# ..   ...     ...   ...       ...                  ...        ...       ...
# 290   28  female  33.4         0                   no  southwest   3172.02
# 888   22    male  39.5         0                   no  southwest   1682.60
# 294   25    male  26.8         3                   no  southwest   3906.13
# 918   61  female  28.2         0                   no  southwest  13041.92
# 0     19  female  27.9         0                  yes  southwest  16884.92
#
#        premium
# 668  1828.4084
# 319    93.3522
# 844   201.4412
# ...

# %% [markdown]
# # Sorting every elements based on gender and  region column

# %%
df.sort_values(["gender","region"])
# Out:
#       age  gender   bmi  children discount_eligibility     region  expenses  \
# 16     52  female  30.8         1                   no  northeast  10797.34
# 20     60  female  36.0         0                   no  northeast  13228.85
# 23     34  female  31.9         1                  yes  northeast  37701.88
# 26     63  female  23.1         0                   no  northeast  14451.84
# 31     18  female  26.3         0                   no  northeast   2198.19
# ...   ...     ...   ...       ...                  ...        ...       ...
# 1295   20    male  22.0         1                   no  southwest   1964.78
# 1303   43    male  27.8         0                  yes  southwest  37829.72
# 1309   41    male  32.2         2                   no  southwest   6875.96
# 1312   34    male  42.9         1                   no  southwest   4536.26
# 1329   52    male  38.6         2                   no  southwest  10325.21
#
#        premium
# 16    215.9468
# 20    264.5770
# ...

# %% [markdown]
# # unqiue values show

# %%
df["region"].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %% [markdown]
# # show unique value numbers

# %%
df["region"].nunique()
# Out:
# 4

# %% [markdown]
# # Checking duplicate values

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %% [markdown]
# # Checking for group by values

# %%
regions = df.groupby("region")
regions

# %%
len(df)
# Out:
# 1338

# %%
len("regions")
# Out:
# 7

# %%
regions.size()
# Out:
# region
# northeast    324
# northwest    325
# southeast    364
# southwest    325
# dtype: int64

# %%
regions.first()
# Out:
#            age  gender   bmi  children discount_eligibility  expenses  \
# region
# northeast   37    male  29.8         2                   no   6406.41
# northwest   33    male  22.7         0                   no  21984.47
# southeast   18    male  33.8         1                   no   1725.55
# southwest   19  female  27.9         0                  yes  16884.92
#
#             premium
# region
# northeast  128.1282
# northwest  439.6894
# southeast   17.2555
# southwest  168.8492

# %% [markdown]
# # Data Visualization

# %%
df["region"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='region'>

# %% [markdown]
# # To check Embarked ratio

# %%
df["gender"].value_counts().plot(kind = "pie")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # To check Embarked ratio

# %%
df["gender"].value_counts().plot(kind = "pie",autopct=" %1.1f%% ", title ="gender distribution")
plt.ylabel(' ')
plt.show()

# %% [markdown]
# # Age Distributuion

# %%
sns.histplot(df["age"])
plt.title(f"age")
plt.show()

# %% [markdown]
# # Count plot

# %%
sns.countplot(x="region" ,data = df)
plt.show()

# %%
sns.countplot(x="region",data = df , hue = "region")
plt.show()

# %%
sns.countplot( x = "gender" ,data = df , hue = "gender")
plt.show()

# %% [markdown]
# # Histplot for checking Age groups

# %%
sns.histplot(df["age" ],kde = True)
plt.show()

# %%
sns.displot(df["gender"])

# %%
sns.pairplot(df,hue="region")
