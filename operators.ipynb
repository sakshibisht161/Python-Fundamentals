# %%
#swapping of two numbers usnig third variable:
a=3
b=6
temp=a
a=b
b=temp
print("a:",a)
print("b:",b)
# Out:
# a: 6
# b: 3

# %%
x=30
y=40
temp=x
x=y
y=temp
print("x:",x)
print("y:",y)
# Out:
# x: 40
# y: 30

# %%
c=2
d=4
temp=c
c=d
d=temp
print("c:",c)
print("d:",d)
# Out:
# c: 4
# d: 2

# %%
x=10
y=20
temp=x
x=y
y=temp
print("x:",x)
print("y:",y)
# Out:
# x: 20
# y: 10

# %%
#without using third variable 
a=3
b=2
a,b=b,a
print("a:",a)
print("b:",b)
# Out:
# a: 2
# b: 3

# %%
c=2
d=4
c,d=d,c
print("c:",c)
print("d:",d)
# Out:
# c: 4
# d: 2

# %%
x=10
y=20
x,y=y,x
print("x:",x)
print("y:",y)
# Out:
# x: 20
# y: 10

# %%
x=30
y=40
x,y=y,x
print("x:",x)
print("y:",y)
# Out:
# x: 40
# y: 30

# %%
#addition of two numbers ;
a=2
b=3
c=a+b
print(c)
# Out:
# 5

# %%
a=5
b=2
c=a-b
print(c)
# Out:
# 3

# %%
a=5
b=2
c=a*b
print(c)
# Out:
# 10

# %%
a=10
b=2
c=a/b
print(c)
# Out:
# 5.0

# %%
a=11
b=2
c=a//b
print(c)
# Out:
# 5

# %%
a=11
b=2
c=a%b
print(c)
# Out:
# 1

# %%
a=11
b=2
c=a/b
print(c)
# Out:
# 5.5

# %%
a=5
b=2
c=a+b
print(c)
c=a-b
print(c)
c=a*b
print(c)
c=a/b
print(c)
c=a//b
print(c)
c=a%b
print(c)
# Out:
# 7
# 3
# 10
# 2.5
# 2
# 1

# %%
#area of circle

# %%
r=2
a=22/7*r*r
print(a)
# Out:
# 12.571428571428571

# %%
#Area of square

# %%
r=2
a=r*r
print(a)
# Out:
# 4

# %%
# area of rectangle

# %%
a=4
b=5
c=a*b
print(c)
# Out:
# 20

# %%
#area of triangle

# %%
a=4
b=5
c=1/2*a*b
print(c)
# Out:
# 10.0

# %%
a=int(input("enter a number"))
b=int(input("enter a number"))
sum=a+b
print(sum)
# Out:
# enter a number 15
# enter a number 20
# 35

# %%
a=int(input("enter a number"))
b=int(input("enter a number"))
sum=a+b
print("addition of two numbers:", sum)
# Out:
# enter a number 100
# enter a number 200
# addition of two numbers: 300

# %%
a=int(input("enter a number"))
b=int(input("enter a number"))
sub=a-b
print("subtraction of two numbers:", sub)
# Out:
# enter a number 500
# enter a number 400
# subtraction of two numbers: 100

# %%
a=int(input("enter a number"))
b=int(input("enter a number"))
mul=a*b
print("multiplication of two numbers:", mul)
# Out:
# enter a number 35
# enter a number 12
# multiplication of two numbers: 420

# %%
a=int(input("enter a number"))
b=int(input("enter a number"))
div=a/b
print("division of two numbers:", div)
# Out:
# enter a number 500
# enter a number 5
# division of two numbers: 100.0

# %%
#finding a simple interset

# %%
p=500
r=4
t=1
si=p*r*t/100
print(si)
# Out:
# 20.0

# %%
p=2000
r=4
t=1
si=p*r*t/100
print(si)
# Out:
# 80.0

# %%
p=5000
r=10
t=2
si=p*r*t/100
print(si)
# Out:
# 1000.0

# %%
a=3
b=4
c=a+b
print(c)
# Out:
# 7

# %%
#convert celsius to fahrenheit

# %%
c=25
f=(c*9/5)+25
print(f)
# Out:
# 70.0

# %%
temp=45
f=(temp*9/5)+45
print(f)
# Out:
# 126.0
