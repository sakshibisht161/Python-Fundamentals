# %% [markdown]
# # Health Data

# %% [markdown]
# # Import All Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # Import Data

# %%
df = pd.read_csv(r"C:\Users\Dell Latitude 5480\Downloads\Health_data.csv")

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %% [markdown]
# # Displaying first 5 records

# %%
df.head(5)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %% [markdown]
# # Displaying last 5 records

# %%
df.tail(5)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %% [markdown]
# # Displaying random 5 records

# %%
df.sample(5)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 157        60    100       120     270.4
# 60        210    108       160    1376.0
# 153        30    150       167     275.8
# 119        60    103       124     332.7
# 2          60    103       135     340.0

# %% [markdown]
# # Checking no of Rows & columns in dataset

# %%
df.shape
# Out:
# (169, 4)

# %% [markdown]
# # Checking all information of Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %% [markdown]
# # Statistical Summary of Data

# %%
df.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %% [markdown]
# # Checking Null values

# %%
df.isnull()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0       False  False     False     False
# 1       False  False     False     False
# 2       False  False     False     False
# 3       False  False     False     False
# 4       False  False     False     False
# ..        ...    ...       ...       ...
# 164     False  False     False     False
# 165     False  False     False     False
# 166     False  False     False     False
# 167     False  False     False     False
# 168     False  False     False     False
#
# [169 rows x 4 columns]

# %% [markdown]
# # Checking Total Null values

# %%
df.isnull().sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %% [markdown]
# # Transpose of Statistical summary of data

# %%
df.describe().T
# Out:
#           count        mean         std    min      25%    50%    75%     max
# Duration  169.0   63.846154   42.299949   15.0   45.000   60.0   60.0   300.0
# Pulse     169.0  107.461538   14.510259   80.0  100.000  105.0  111.0   159.0
# Maxpulse  169.0  134.047337   16.450434  100.0  124.000  131.0  141.0   184.0
# Calories  164.0  375.790244  266.379919   50.3  250.925  318.6  387.6  1860.4

# %% [markdown]
# # Checking every elements of total count in a column

# %%
df["Duration"].value_counts()
# Out:
# Duration
# 60     79
# 45     35
# 30     16
# 20      9
# 90      8
# 150     4
# 180     3
# 120     3
# 210     2
# 160     2
# 15      2
# 75      2
# 80      1
# 300     1
# 270     1
# 25      1
# Name: count, dtype: int64

# %% [markdown]
# # Sorting every elements of total count in a column

# %%
df["Duration"].value_counts().sort_values()
# Out:
# Duration
# 80      1
# 300     1
# 270     1
# 25      1
# 210     2
# 160     2
# 15      2
# 75      2
# 180     3
# 120     3
# 150     4
# 90      8
# 20      9
# 30     16
# 45     35
# 60     79
# Name: count, dtype: int64

# %% [markdown]
# # Descending order sorting

# %%
df["Duration"].value_counts().sort_values(ascending = False)
# Out:
# Duration
# 60     79
# 45     35
# 30     16
# 20      9
# 90      8
# 150     4
# 180     3
# 120     3
# 210     2
# 160     2
# 15      2
# 75      2
# 80      1
# 300     1
# 270     1
# 25      1
# Name: count, dtype: int64

# %% [markdown]
# # Sorting every elements based on Pulse column

# %%
df.sort_values("Pulse")
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 159        30     80       120     240.9
# 93         15     80       100      50.5
# 89         20     83       107      50.3
# 160        30     85       120     250.4
# 92         30     90       107     105.3
# ..        ...    ...       ...       ...
# 85         30    151       170     300.0
# 95         20    151       168     229.4
# 97         25    152       168     244.2
# 58         20    153       172     226.4
# 80         30    159       182     319.2
#
# [169 rows x 4 columns]

# %% [markdown]
# # Sorting every elements based on Maxpulse and Calories column

# %%
df.sort_values(["Maxpulse","Calories"])
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 93         15     80       100      50.5
# 102        90     90       100     500.0
# 103        90     90       100     500.4
# 22         60    130       101     300.0
# 88         45    129       103     242.0
# ..        ...    ...       ...       ...
# 58         20    153       172     226.4
# 54         30    136       175     238.0
# 3          45    109       175     282.4
# 80         30    159       182     319.2
# 109       210    137       184    1860.4
#
# [169 rows x 4 columns]

# %% [markdown]
# # Checking duplicate values

# %%
df.duplicated().sum()
# Out:
# np.int64(7)

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # Histplot

# %%
sns.histplot(x = "Pulse" , data = df , kde = True , color ="m")
# Out:
# <Axes: xlabel='Pulse', ylabel='Count'>

# %%
sns.histplot(x = "Maxpulse" , data = df , kde = True , color = "r")
# Out:
# <Axes: xlabel='Maxpulse', ylabel='Count'>

# %% [markdown]
# # Scatter plot

# %%
sns.scatterplot( x = "Duration" , y = "Calories" , data = df , color = "g" )
# Out:
# <Axes: xlabel='Duration', ylabel='Calories'>

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(df,hue ="Duration")
