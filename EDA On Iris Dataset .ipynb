# %% [markdown]
# # Iris Dataset

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Dell Latitude 5480\Downloads\archive (8).zip")

# %%
df
# Out:
#      sepal-length  sepal-width  petal-length  petal-width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Displaying first 5 records

# %%
df.head(5)
# Out:
#    sepal-length  sepal-width  petal-length  petal-width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# # Displaying last 5 records

# %%
df.tail(5)
# Out:
#      sepal-length  sepal-width  petal-length  petal-width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %% [markdown]
# # Displaying sample 5 records

# %%
df.sample(5)
# Out:
#      sepal-length  sepal-width  petal-length  petal-width          species
# 72            6.3          2.5           4.9          1.5  Iris-versicolor
# 142           5.8          2.7           5.1          1.9   Iris-virginica
# 119           6.0          2.2           5.0          1.5   Iris-virginica
# 64            5.6          2.9           3.6          1.3  Iris-versicolor
# 128           6.4          2.8           5.6          2.1   Iris-virginica

# %% [markdown]
# # Checking no of Rows & columns in dataset

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# # Checking all information of Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal-length  150 non-null    float64
#  1   sepal-width   150 non-null    float64
#  2   petal-length  150 non-null    float64
#  3   petal-width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# # Statistical Summary of Data

# %%
df.describe()
# Out:
#        sepal-length  sepal-width  petal-length  petal-width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# # Checking Null values

# %%
df.isnull()
# Out:
#      sepal-length  sepal-width  petal-length  petal-width  species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %% [markdown]
# # Checking Total Null values

# %%
df.isnull().sum()
# Out:
# sepal-length    0
# sepal-width     0
# petal-length    0
# petal-width     0
# species         0
# dtype: int64

# %% [markdown]
# # Transpose of Statistical summary of data

# %%
df.describe().T
# Out:
#               count      mean       std  min  25%   50%  75%  max
# sepal-length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# sepal-width   150.0  3.054000  0.433594  2.0  2.8  3.00  3.3  4.4
# petal-length  150.0  3.758667  1.764420  1.0  1.6  4.35  5.1  6.9
# petal-width   150.0  1.198667  0.763161  0.1  0.3  1.30  1.8  2.5

# %% [markdown]
# # Checking every elements of total count in a column

# %%
df["species"].value_counts()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# # Sorting every elements of total count in a column

# %%
df["species"].value_counts().sort_values()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# # Sorting every elements based on petal-length column

# %%
df.sort_values("petal-length")
# Out:
#      sepal-length  sepal-width  petal-length  petal-width         species
# 22            4.6          3.6           1.0          0.2     Iris-setosa
# 13            4.3          3.0           1.1          0.1     Iris-setosa
# 14            5.8          4.0           1.2          0.2     Iris-setosa
# 35            5.0          3.2           1.2          0.2     Iris-setosa
# 36            5.5          3.5           1.3          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 131           7.9          3.8           6.4          2.0  Iris-virginica
# 105           7.6          3.0           6.6          2.1  Iris-virginica
# 117           7.7          3.8           6.7          2.2  Iris-virginica
# 122           7.7          2.8           6.7          2.0  Iris-virginica
# 118           7.7          2.6           6.9          2.3  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Sorting every elements based on petal-length and petal-width column

# %%
df.sort_values(["petal-length","petal-width"])
# Out:
#      sepal-length  sepal-width  petal-length  petal-width         species
# 22            4.6          3.6           1.0          0.2     Iris-setosa
# 13            4.3          3.0           1.1          0.1     Iris-setosa
# 14            5.8          4.0           1.2          0.2     Iris-setosa
# 35            5.0          3.2           1.2          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 131           7.9          3.8           6.4          2.0  Iris-virginica
# 105           7.6          3.0           6.6          2.1  Iris-virginica
# 122           7.7          2.8           6.7          2.0  Iris-virginica
# 117           7.7          3.8           6.7          2.2  Iris-virginica
# 118           7.7          2.6           6.9          2.3  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # unique values show

# %%
df["species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# # show unique values number

# %%
df["species"].nunique()
# Out:
# 3

# %% [markdown]
# # Checking duplicate values

# %%
df.duplicated().sum()
# Out:
# np.int64(3)

# %% [markdown]
# # Checking for group by values

# %%
specie = df.groupby("species")
specie

# %%
len(df)
# Out:
# 150

# %%
len("specie")
# Out:
# 6

# %%
specie.size()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
specie.first()
# Out:
#                  sepal-length  sepal-width  petal-length  petal-width
# species
# Iris-setosa               5.1          3.5           1.4          0.2
# Iris-versicolor           7.0          3.2           4.7          1.4
# Iris-virginica            6.3          3.3           6.0          2.5

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # Bar chart

# %%
df["species"].value_counts().plot(kind = "bar" , color = "y")
# Out:
# <Axes: xlabel='species'>

# %% [markdown]
# # Histplot

# %%
sns.histplot(x = "sepal-length" ,data = df , kde = True ,color ="g" )
# Out:
# <Axes: xlabel='sepal-length', ylabel='Count'>

# %%
sns.histplot(x = "sepal-width" ,data = df , kde = True ,color = "m")
# Out:
# <Axes: xlabel='sepal-width', ylabel='Count'>

# %% [markdown]
# # Scatterplot

# %%
sns.scatterplot(x= "petal-length" , y = "petal-width", data = df , hue = "species")
# Out:
# <Axes: xlabel='petal-length', ylabel='petal-width'>

# %% [markdown]
# # Boxplot

# %%
sns.boxplot( x = "species" , y = "sepal-width" , data = df , hue = "species")
# Out:
# <Axes: xlabel='species', ylabel='sepal-width'>

# %% [markdown]
# # Countplot

# %%
sns.countplot(x = "species" , data = df , palette = "Set2")
# Out:
# C:\Users\Dell Latitude 5480\AppData\Local\Temp\ipykernel_3324\1920361097.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = "species" , data = df , palette = "Set2")
# <Axes: xlabel='species', ylabel='count'>

# %% [markdown]
# # displot

# %%
sns.displot(x = "species" , data = df , color = "r")

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(df,hue="species")
