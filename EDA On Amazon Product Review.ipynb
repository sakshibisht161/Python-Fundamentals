# %% [markdown]
# # Amazon Product Review

# %% [markdown]
# # Import All Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # Import Data

# %%
df = pd.read_csv(r"C:\Users\Dell Latitude 5480\Downloads\archive (9).zip")

# %%
df
# Out:
#             Id   ProductId          UserId                      ProfileName  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3            4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...        ...         ...             ...                              ...
# 568449  568450  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 568450  568451  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 568451  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 568452  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 568453  568454  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
# ...

# %% [markdown]
# # Displaying first 5 records

# %%
df.head(5)
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %% [markdown]
# # Displaying last 5 records

# %%
df.tail(5)
# Out:
#             Id   ProductId          UserId              ProfileName  \
# 568449  568450  B001EO7N10  A28KG5XORO54AY         Lettie D. Carter
# 568450  568451  B003S1WTCU  A3I8AFVPEE8KI5                R. Sawyer
# 568451  568452  B004I613EE  A121AA1GQV751Z            pksd "pk_007"
# 568452  568453  B004I613EE   A3IBEVCTXKNOH  Kathy A. Welch "katwel"
# 568453  568454  B001LR2CU2  A3LGQPJCZVL9UC                 srfell17
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 568449                     0                       0      5  1299628800
# 568450                     0                       0      2  1331251200
# 568451                     2                       2      5  1329782400
# 568452                     1                       1      5  1331596800
# 568453                     0                       0      5  1338422400
#
#                                    Summary  \
# 568449                 Will not do without
# ...

# %% [markdown]
# # Displaying random 5 records

# %%
df.sample(5)
# Out:
#             Id   ProductId          UserId                ProfileName  \
# 509522  509523  B00008DFOM  A13IH5VW8O9DNT                   ttroxell
# 444298  444299  B003EMSSGE   ABL9V16XN7W1X                     liasue
# 225686  225687  B002ZX1U9A  A13YDB1VA6XW8T  A. Cornell "coffee lover"
# 566453  566454  B004R8L71W  A1Q08H4B9QGT2N  Christy "MommyOfRedHeads"
# 62091    62092  B000CQG8K8  A1I4R2UYQQR1MH          A.P.G. "The Doc."
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 509522                     1                       1      1  1317772800
# 444298                     0                       0      5  1316131200
# 225686                     2                       3      2  1253577600
# 566453                     0                       0      4  1312848000
# 62091                      2                       2      4  1236988800
#
#                                    Summary  \
# 509522                   not as advertised
# ...

# %% [markdown]
# # Checking no of Rows & columns in dataset

# %%
df.shape
# Out:
# (568454, 10)

# %% [markdown]
# # Checking all information of Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568454 entries, 0 to 568453
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Id                      568454 non-null  int64
#  1   ProductId               568454 non-null  object
#  2   UserId                  568454 non-null  object
#  3   ProfileName             568428 non-null  object
#  4   HelpfulnessNumerator    568454 non-null  int64
#  5   HelpfulnessDenominator  568454 non-null  int64
#  6   Score                   568454 non-null  int64
#  7   Time                    568454 non-null  int64
#  8   Summary                 568427 non-null  object
#  9   Text                    568454 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 43.4+ MB

# %% [markdown]
# # Statistical Summary of Data

# %%
df.describe()
# Out:
#                   Id  HelpfulnessNumerator  HelpfulnessDenominator  \
# count  568454.000000         568454.000000            568454.00000
# mean   284227.500000              1.743817                 2.22881
# std    164098.679298              7.636513                 8.28974
# min         1.000000              0.000000                 0.00000
# 25%    142114.250000              0.000000                 0.00000
# 50%    284227.500000              0.000000                 1.00000
# 75%    426340.750000              2.000000                 2.00000
# max    568454.000000            866.000000               923.00000
#
#                Score          Time
# count  568454.000000  5.684540e+05
# mean        4.183199  1.296257e+09
# std         1.310436  4.804331e+07
# min         1.000000  9.393408e+08
# 25%         4.000000  1.271290e+09
# 50%         5.000000  1.311120e+09
# 75%         5.000000  1.332720e+09
# max         5.000000  1.351210e+09

# %% [markdown]
# # Checking Null values

# %%
df.isnull()
# Out:
#            Id  ProductId  UserId  ProfileName  HelpfulnessNumerator  \
# 0       False      False   False        False                 False
# 1       False      False   False        False                 False
# 2       False      False   False        False                 False
# 3       False      False   False        False                 False
# 4       False      False   False        False                 False
# ...       ...        ...     ...          ...                   ...
# 568449  False      False   False        False                 False
# 568450  False      False   False        False                 False
# 568451  False      False   False        False                 False
# 568452  False      False   False        False                 False
# 568453  False      False   False        False                 False
#
#         HelpfulnessDenominator  Score   Time  Summary   Text
# 0                        False  False  False    False  False
# ...

# %% [markdown]
# # Checking Total Null values

# %%
df.isnull().sum()
# Out:
# Id                         0
# ProductId                  0
# UserId                     0
# ProfileName               26
# HelpfulnessNumerator       0
# HelpfulnessDenominator     0
# Score                      0
# Time                       0
# Summary                   27
# Text                       0
# dtype: int64

# %% [markdown]
# # Transpose of Statistical summary of data

# %%
df.describe().T
# Out:
#                            count          mean           std          min  \
# Id                      568454.0  2.842275e+05  1.640987e+05          1.0
# HelpfulnessNumerator    568454.0  1.743817e+00  7.636513e+00          0.0
# HelpfulnessDenominator  568454.0  2.228810e+00  8.289740e+00          0.0
# Score                   568454.0  4.183199e+00  1.310436e+00          1.0
# Time                    568454.0  1.296257e+09  4.804331e+07  939340800.0
#
#                                  25%           50%           75%           max
# Id                      1.421142e+05  2.842275e+05  4.263408e+05  5.684540e+05
# HelpfulnessNumerator    0.000000e+00  0.000000e+00  2.000000e+00  8.660000e+02
# HelpfulnessDenominator  0.000000e+00  1.000000e+00  2.000000e+00  9.230000e+02
# Score                   4.000000e+00  5.000000e+00  5.000000e+00  5.000000e+00
# Time                    1.271290e+09  1.311120e+09  1.332720e+09  1.351210e+09

# %% [markdown]
# # Checking every elements of total count in a column

# %%
df["ProfileName"].value_counts()
# Out:
# ProfileName
# C. F. Hill "CFH"                               451
# O. Brown "Ms. O. Khannah-Brown"                421
# Gary Peterson                                  389
# Rebecca of Amazon "The Rebecca Review"         365
# Chris                                          363
#                                               ...
# Steven Wolff                                     1
# joycomeau                                        1
# Lizz                                             1
# Phyllis A. De Smet-Howard "tweedsmerewillo"      1
# srfell17                                         1
# Name: count, Length: 218415, dtype: int64

# %% [markdown]
# # Sorting every elements of total count in a column

# %%
df["ProfileName"].value_counts().sort_values()
# Out:
# ProfileName
# K. Pirimoglu                                1
# Lucille G. Kialashaki "lucyk"               1
# Panda Farm                                  1
# Clau                                        1
# Judith M. Gerharz "book lover"              1
#                                          ...
# Chris                                     363
# Rebecca of Amazon "The Rebecca Review"    365
# Gary Peterson                             389
# O. Brown "Ms. O. Khannah-Brown"           421
# C. F. Hill "CFH"                          451
# Name: count, Length: 218415, dtype: int64

# %% [markdown]
# # Descending order sorting

# %%
df["ProfileName"].value_counts().sort_values(ascending = False)
# Out:
# ProfileName
# C. F. Hill "CFH"                          451
# O. Brown "Ms. O. Khannah-Brown"           421
# Gary Peterson                             389
# Rebecca of Amazon "The Rebecca Review"    365
# Chris                                     363
#                                          ...
# Michael Helferd                             1
# James Mackinnon "aka, DJ Jimmer"            1
# Leroy Smith                                 1
# Robert D. Beving                            1
# srfell17                                    1
# Name: count, Length: 218415, dtype: int64

# %% [markdown]
# # Sorting every elements based on HelpfulnessNumerator column

# %%
df.sort_values("HelpfulnessNumerator")
# Out:
#             Id   ProductId          UserId                     ProfileName  \
# 284226  284227  B0051COPH6   A6X1O3A5C5FX1                             SMB
# 321993  321994  B0012V1G0Y  A1TK8KY9NP2UPT   Medusa "She's a Lovely Girl!"
# 321992  321993  B0012V1G0Y  A1YYA472ZYUJ30                     Simon's Mom
# 321991  321992  B0012V1G0Y  A37JJA4K2OY256                   cardsstunt101
# 321990  321991  B0012V1G0Y  A1BD342U8BF3UC                         Britney
# ...        ...         ...             ...                             ...
# 467800  467801  B0065G59F4  A1B4MIXYVIKMU2  D. Truong "Duke of New Mexico"
# 235722  235723  B001F10XUU  A39V22BIBUMMB3       Y. Hughes "Notmyrealname"
# 566779  566780  B001PQTYN2  A1QB2Y8GSME58Y               Benjamin Chodroff
# 207712  207713  B00012182G  A1JUGIQDY6UYSM           BabbChuck "BabbChuck"
# 190733  190734  B000FI4O90  A1GQGYROVZVW49                      P. Schmidt
#
# ...

# %% [markdown]
# # Sorting every elements based on HelpfulnessNumerator and HelpfulnessDenominator column

# %%
df.sort_values(["HelpfulnessNumerator","HelpfulnessDenominator"])
# Out:
#             Id   ProductId          UserId                     ProfileName  \
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                          dll pa
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T   Michael D. Bigham "M. Wassir"
# 5            6  B006K2ZZ7K   ADT0SRK1MGOEU                  Twoapennything
# 6            7  B006K2ZZ7K  A1SP2KVKFXXRU1               David C. Sullivan
# 7            8  B006K2ZZ7K  A3JRGQVEQN31IQ              Pamela G. Williams
# ...        ...         ...             ...                             ...
# 467800  467801  B0065G59F4  A1B4MIXYVIKMU2  D. Truong "Duke of New Mexico"
# 235722  235723  B001F10XUU  A39V22BIBUMMB3       Y. Hughes "Notmyrealname"
# 566779  566780  B001PQTYN2  A1QB2Y8GSME58Y               Benjamin Chodroff
# 207712  207713  B00012182G  A1JUGIQDY6UYSM           BabbChuck "BabbChuck"
# 190733  190734  B000FI4O90  A1GQGYROVZVW49                      P. Schmidt
#
# ...

# %% [markdown]
# # unique values show

# %%
df["Score"].unique()
# Out:
# array([5, 1, 4, 2, 3])

# %% [markdown]
# # show unique values number

# %%
df["Score"].nunique()
# Out:
# 5

# %% [markdown]
# # Checking duplicate values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Checking for group by values

# %%
Scores = df.groupby("Score")
Scores

# %%
len(df)
# Out:
# 568454

# %%
len("Scores")
# Out:
# 6

# %%
Scores.size()
# Out:
# Score
# 1     52268
# 2     29769
# 3     42640
# 4     80655
# 5    363122
# dtype: int64

# %%
Scores.first()
# Out:
#        Id   ProductId          UserId                      ProfileName  \
# Score
# 1       2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2       4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 3      46  B001EO5QW8  A39Z97950MCTQE                      K. A. Freel
# 4       3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 5       1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
#
#        HelpfulnessNumerator  HelpfulnessDenominator        Time  \
# Score
# 1                         0                       0  1346976000
# 2                         3                       3  1307923200
# 3                         0                       0  1205193600
# 4                         1                       1  1219017600
# 5                         1                       1  1303862400
#
#                      Summary  \
# Score
# 1          Not as Advertised
# 2             Cough Medicine
# 3             Hearty Oatmeal
# ...

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # Histplot

# %%
sns.histplot(x ="Score", data = df, color="c" , kde = True)
# Out:
# <Axes: xlabel='Score', ylabel='Count'>

# %% [markdown]
# # Scatter plot

# %%
sns.scatterplot(x = "HelpfulnessNumerator",y ="HelpfulnessDenominator" , data = df , color ="m")
# Out:
# <Axes: xlabel='HelpfulnessNumerator', ylabel='HelpfulnessDenominator'>
