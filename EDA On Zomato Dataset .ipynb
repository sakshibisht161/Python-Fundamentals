# %% [markdown]
# # Zomato Dataset

# %% [markdown]
# # Import All Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # Import Data

# %%
df = pd.read_csv(r"C:\Users\Dell Latitude 5480\Downloads\archive (11).zip")

# %%
df
# Out:
#                       name online_order book_table   rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1/5    775
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 143       Melting Melodies           No         No  3.3/5      0
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %% [markdown]
# # Displaying first 5 records

# %%
df.head(5)
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %% [markdown]
# # Displaying last 5 records

# %%
df.tail(5)
# Out:
#                  name online_order book_table   rate  votes  \
# 143  Melting Melodies           No         No  3.3/5      0
# 144   New Indraprasta           No         No  3.3/5      0
# 145      Anna Kuteera          Yes         No  4.0/5    771
# 146            Darbar           No         No  3.0/5     98
# 147     Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 143                          100          Dining
# 144                          150          Dining
# 145                          450          Dining
# 146                          800          Dining
# 147                          200          Dining

# %% [markdown]
# # Displaying Random 5 records

# %%
df.sample(5)
# Out:
#                                  name online_order book_table   rate  votes  \
# 113  Dharwad Line Bazaar Mishra Pedha           No         No  3.4/5      0
# 88                       Dessert Rose           No         No  3.5/5      7
# 145                      Anna Kuteera          Yes         No  4.0/5    771
# 134                   Kaumudis Juoice           No         No  3.3/5      0
# 108      Naveen Kabab & Biriyani Mane           No         No  3.2/5      9
#
#      approx_cost(for two people) listed_in(type)
# 113                          150          Dining
# 88                           500          Dining
# 145                          450          Dining
# 134                          150          Dining
# 108                          300          Dining

# %% [markdown]
# # Checking no of Rows & columns in dataset

# %%
df.shape
# Out:
# (148, 7)

# %% [markdown]
# # Checking all information of Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    object
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 8.2+ KB

# %% [markdown]
# # Statistical Summary of Data

# %%
df.describe()
# Out:
#              votes  approx_cost(for two people)
# count   148.000000                   148.000000
# mean    264.810811                   418.243243
# std     653.676951                   223.085098
# min       0.000000                   100.000000
# 25%       6.750000                   200.000000
# 50%      43.500000                   400.000000
# 75%     221.750000                   600.000000
# max    4884.000000                   950.000000

# %% [markdown]
# # Checking Null values

# %%
df.isnull()
# Out:
#       name  online_order  book_table   rate  votes  \
# 0    False         False       False  False  False
# 1    False         False       False  False  False
# 2    False         False       False  False  False
# 3    False         False       False  False  False
# 4    False         False       False  False  False
# ..     ...           ...         ...    ...    ...
# 143  False         False       False  False  False
# 144  False         False       False  False  False
# 145  False         False       False  False  False
# 146  False         False       False  False  False
# 147  False         False       False  False  False
#
#      approx_cost(for two people)  listed_in(type)
# 0                          False            False
# 1                          False            False
# 2                          False            False
# 3                          False            False
# 4                          False            False
# ...

# %% [markdown]
# # Checking Total Null values

# %%
df.isnull().sum()
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# approx_cost(for two people)    0
# listed_in(type)                0
# dtype: int64

# %% [markdown]
# # Transpose of Statistical summary of data

# %%
df.describe().T
# Out:
#                              count        mean         std    min     25%  \
# votes                        148.0  264.810811  653.676951    0.0    6.75
# approx_cost(for two people)  148.0  418.243243  223.085098  100.0  200.00
#
#                                50%     75%     max
# votes                         43.5  221.75  4884.0
# approx_cost(for two people)  400.0  600.00   950.0

# %% [markdown]
# # Checking every elements of total count in a column

# %%
df["listed_in(type)"].value_counts()
# Out:
# listed_in(type)
# Dining    110
# Cafes      23
# other       8
# Buffet      7
# Name: count, dtype: int64

# %% [markdown]
# # Sorting every elements of total count in a column

# %%
df["listed_in(type)"].value_counts().sort_values()
# Out:
# listed_in(type)
# Buffet      7
# other       8
# Cafes      23
# Dining    110
# Name: count, dtype: int64

# %% [markdown]
# # Descending order sorting

# %%
df["listed_in(type)"].value_counts().sort_values(ascending = False)
# Out:
# listed_in(type)
# Dining    110
# Cafes      23
# other       8
# Buffet      7
# Name: count, dtype: int64

# %% [markdown]
# # Sorting every elements based on listed_in(type) column

# %%
df.sort_values("listed_in(type)")
# Out:
#                      name online_order book_table   rate  votes  \
# 0                   Jalsa          Yes        Yes  4.1/5    775
# 1          Spice Elephant          Yes         No  4.1/5    787
# 2         San Churro Cafe          Yes         No  3.8/5    918
# 3   Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4           Grand Village           No         No  3.8/5    166
# ..                    ...          ...        ...    ...    ...
# 38      Empire Restaurant          Yes         No  4.4/5   4884
# 44                 Onesta          Yes        Yes  4.6/5   2556
# 60          Peppy Peppers           No         No  4.2/5    244
# 34                 Faasos          Yes         No  4.2/5    415
# 73               LSD Cafe           No         No  2.9/5     84
#
#     approx_cost(for two people) listed_in(type)
# 0                           800          Buffet
# 1                           800          Buffet
# 2                           800          Buffet
# ...

# %% [markdown]
# # Sorting every elements based on listed_in(type) and online_order column

# %%
df.sort_values(["listed_in(type)","online_order"])
# Out:
#                                                name online_order book_table  \
# 3                             Addhuri Udupi Bhojana           No         No
# 4                                     Grand Village           No         No
# 6   Rosewood International Hotel - Bar & Restaurant           No         No
# 0                                             Jalsa          Yes        Yes
# 1                                    Spice Elephant          Yes         No
# ..                                              ...          ...        ...
# 31                                       Foodiction          Yes         No
# 34                                           Faasos          Yes         No
# 38                                Empire Restaurant          Yes         No
# 44                                           Onesta          Yes        Yes
# 57                                           Wamama          Yes        Yes
#
# ...

# %% [markdown]
# # unique values show

# %%
df["book_table"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# # show unique values number

# %%
df["book_table"].nunique()
# Out:
# 2

# %% [markdown]
# # Checking duplicate values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # Bar chart

# %%
df["listed_in(type)"].value_counts().plot(kind ="bar" , color = "purple")
# Out:
# <Axes: xlabel='listed_in(type)'>

# %% [markdown]
# # Pie Chart

# %%
df["online_order"].value_counts().plot(kind ="pie" )
# Out:
# <Axes: ylabel='count'>

# %%
df["online_order"].value_counts().plot(kind ="pie" ,autopct = "%1.1f%%" , title = "online_order distribution")
plt.ylabel(' ')
plt.show()

# %% [markdown]
# # Scatter plot

# %%
sns.scatterplot(x = "listed_in(type)",y ="votes" , data = df , hue ="book_table")
# Out:
# <Axes: xlabel='listed_in(type)', ylabel='votes'>

# %% [markdown]
# # Displot

# %%
sns.displot(x = "book_table" , data = df , color ="m")

# %% [markdown]
# # Count plot

# %%
sns.countplot( x = "online_order" , data = df , color = "teal")
# Out:
# <Axes: xlabel='online_order', ylabel='count'>

# %% [markdown]
# # Pair plot

# %%
sns.pairplot(df,hue ="listed_in(type)")
